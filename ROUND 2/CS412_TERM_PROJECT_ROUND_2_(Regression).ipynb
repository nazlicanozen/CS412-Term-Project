# %%
# !pip install xgboost==1.7.6
# Out:
# Collecting xgboost==1.7.6
#   Downloading xgboost-1.7.6-py3-none-manylinux2014_x86_64.whl.metadata (1.9 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from xgboost==1.7.6) (1.26.4)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from xgboost==1.7.6) (1.13.1)
# Downloading xgboost-1.7.6-py3-none-manylinux2014_x86_64.whl (200.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 200.3/200.3 MB 5.2 MB/s eta 0:00:00
# Installing collected packages: xgboost
#   Attempting uninstall: xgboost
#     Found existing installation: xgboost 2.1.3
#     Uninstalling xgboost-2.1.3:
#       Successfully uninstalled xgboost-2.1.3
# Successfully installed xgboost-1.7.6

# %%
import gzip
import json
import random

# Path to the gzipped dataset
data_path = "training-dataset.jsonl.gz"

# Initialize dictionaries for train and test data
train_data = {"profiles": {}, "posts": {}}
test_data = {"profiles": {}, "posts": {}}

# Load and shuffle the data
data_entries = []

with gzip.open(data_path, "rt") as fh:
    for line in fh:
        sample = json.loads(line)
        data_entries.append(sample)

# Shuffle the data to ensure randomness
random.shuffle(data_entries)

# Define the train-test split ratio
train_ratio = 0.8
train_size = int(len(data_entries) * train_ratio)

# Divide the data into train and test sets
train_post_count = 0
test_post_count = 0

for i, sample in enumerate(data_entries):
    profile = sample["profile"]
    username = profile["username"]
    posts = sample["posts"]

    if i < train_size:
        train_data["profiles"][username] = profile
        train_data["posts"][username] = posts
        train_post_count += len(posts)
    else:
        test_data["profiles"][username] = profile
        test_data["posts"][username] = posts
        test_post_count += len(posts)

# Output the sizes of train and test sets
print(f"Number of users in train data: {len(train_data['profiles'])}")
print(f"Number of posts in train data: {train_post_count}")
print(f"Number of users in test data: {len(test_data['profiles'])}")
print(f"Number of posts in test data: {test_post_count}")
# Out:
# Number of users in train data: 4332
# Number of posts in train data: 149701
# Number of users in test data: 1083
# Number of posts in test data: 37601

# %%
# Function to extract all unique columns (keys) from the posts
def extract_columns_from_data(data):
    columns = set()  # Use a set to store unique column names
    for posts in data["posts"].values():
        for post in posts:
            columns.update(post.keys())  # Add all keys from the current post
    return sorted(columns)  # Return sorted list of unique columns

# Extract columns for train_data and test_data
train_columns = extract_columns_from_data(train_data)
test_columns = extract_columns_from_data(test_data)

# Print the columns
print("Columns in train_data posts:")
print(train_columns)

print("\nColumns in test_data posts:")
print(test_columns)
# Out:
# Columns in train_data posts:
# ['caption', 'comments_count', 'id', 'like_count', 'media_type', 'media_url', 'timestamp']
#
# Columns in test_data posts:
# ['caption', 'comments_count', 'id', 'like_count', 'media_type', 'media_url', 'timestamp']

# %%
import numpy as np
import re
from datetime import datetime
from sklearn.preprocessing import MinMaxScaler

def extract_features_and_targets(data):
    features = []
    targets = []

    for username, posts in data["posts"].items():
        for post in posts:
            caption = post.get("caption", "") or ""

            # Basic text features
            caption_length = len(caption)
            hashtag_count  = caption.count("#")
            mention_count  = caption.count("@")

            # Additional text features
            # -------------------------------------------------------------
            # 1) word_count
            words = caption.strip().split()
            word_count = len(words)
            # 2) average_word_length
            avg_word_len = 0.0
            if word_count > 0:
                avg_word_len = sum(len(w) for w in words) / word_count
            # 3) emoji_count (naive approach: count non-alphanumeric symbols)
            #    or you can be more precise with an emoji regex
            emoji_count = len(re.findall(r'[^\w\s,.;?!@#]', caption))
            # 4) exclamation/question marks
            exclamation_count = caption.count('!')
            question_count    = caption.count('?')
            # 5) link presence
            link_presence = 1 if ('http' in caption or 'www' in caption) else 0
            # -------------------------------------------------------------

            comments_count = post.get("comments_count", 0) or 0
            media_type = 1 if post.get("media_type") == "IMAGE" else 0

            # Time-based features
            timestamp = post.get("timestamp")
            hour = 0
            weekday = 0
            weekend = 0
            if timestamp:
                dt = datetime.fromisoformat(timestamp)
                hour = dt.hour
                weekday = dt.weekday()
                weekend = 1 if dt.weekday() >= 5 else 0

            like_count = post.get("like_count", None)
            if like_count is not None:
                feature = [
                    caption_length,
                    hashtag_count,
                    mention_count,
                    comments_count,
                    media_type,
                    hour,
                    weekday,
                    weekend,
                    # New text features:
                    word_count,
                    avg_word_len,
                    emoji_count,
                    exclamation_count,
                    question_count,
                    link_presence
                ]
                features.append(feature)
                targets.append(int(like_count))  # Ensure target is integer

    return np.array(features), np.array(targets)

# ------------------------------------------------------
# Extract features/targets for train & test
train_features, train_targets = extract_features_and_targets(train_data)
test_features, test_targets   = extract_features_and_targets(test_data)

# Remove outliers in target based on IQR
q1 = np.percentile(train_targets, 25)
q3 = np.percentile(train_targets, 75)
iqr = q3 - q1
lower_bound = q1 - 1.5 * iqr
upper_bound = q3 + 1.5 * iqr
filtered_indices = (train_targets >= lower_bound) & (train_targets <= upper_bound)
train_features = train_features[filtered_indices]
train_targets  = train_targets[filtered_indices]

# We only scale time-based features (hour, weekday), but now they are at indices 5,6
# (Also be mindful if you want to scale other numeric features).
scaler = MinMaxScaler()
train_features[:, 5:7] = scaler.fit_transform(train_features[:, 5:7])
test_features[:, 5:7]  = scaler.transform(test_features[:, 5:7])

# %%
# If not installed:
# %pip install xgboost

import numpy as np
import xgboost as xgb
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score

# 1) Train/validation/test Split
X_train, X_val, y_train, y_val = train_test_split(
    train_features,
    train_targets,
    test_size=0.2,
    random_state=42
)

# 2) Transform the target via log1p
y_train_log = np.log1p(y_train)
y_val_log   = np.log1p(y_val)
y_test_log  = np.log1p(test_targets)

# 3) Create XGB model
# Feel free to adjust hyperparameters
xgb_model = xgb.XGBRegressor(
    n_estimators=1000,
    learning_rate=0.05,
    max_depth=6,
    subsample=0.8,
    colsample_bytree=0.8,
    random_state=42
)

# 4) Train with early stopping on validation set
xgb_model.fit(
    X_train,
    y_train_log,
    eval_set=[(X_val, y_val_log)],
    early_stopping_rounds=25,
    verbose=True
)

# 5) Evaluate on Validation
val_pred_log = xgb_model.predict(X_val)
val_pred     = np.round(np.expm1(val_pred_log)).astype(int)

val_log_mse = np.mean((np.log1p(y_val) - np.log1p(val_pred))**2)
val_r2      = r2_score(y_val, val_pred)
print("XGBoost Validation Log MSE:", val_log_mse)
print("XGBoost Validation R²:", val_r2)

# 6) Evaluate on Test
test_pred_log = xgb_model.predict(test_features)
test_pred     = np.round(np.expm1(test_pred_log)).astype(int)

test_log_mse = np.mean((y_test_log - np.log1p(test_pred))**2)
test_r2      = r2_score(test_targets, test_pred)
print("XGBoost Test Log MSE:", test_log_mse)
print("XGBoost Test R²:", test_r2)

# 7) Some sample predictions
print("\nSample Predictions (XGB):")
for true, pred in zip(test_targets[:10], test_pred[:10]):
    print(f"Actual: {true}, Predicted: {pred}")
# Out:
# /usr/local/lib/python3.10/dist-packages/xgboost/sklearn.py:835: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [0]	validation_0-rmse:3.49346
# [1]	validation_0-rmse:3.33443
# [2]	validation_0-rmse:3.18430
# [3]	validation_0-rmse:3.04259
# [4]	validation_0-rmse:2.90827
# [5]	validation_0-rmse:2.78148
# [6]	validation_0-rmse:2.66217
# [7]	validation_0-rmse:2.54955
# [8]	validation_0-rmse:2.44826
# [9]	validation_0-rmse:2.35328
# [10]	validation_0-rmse:2.25848
# [11]	validation_0-rmse:2.16952
# [12]	validation_0-rmse:2.08580
# [13]	validation_0-rmse:2.00750
# [14]	validation_0-rmse:1.93835
# [15]	validation_0-rmse:1.86911
# [16]	validation_0-rmse:1.80424
# [17]	validation_0-rmse:1.74364
# [18]	validation_0-rmse:1.68699
# [19]	validation_0-rmse:1.63441
# [20]	validation_0-rmse:1.58847
# [21]	validation_0-rmse:1.54258
# [22]	validation_0-rmse:1.50016
# [23]	validation_0-rmse:1.46055
# [24]	validation_0-rmse:1.42402
# [25]	validation_0-rmse:1.39006
# [26]	validation_0-rmse:1.36053
# [27]	validation_0-rmse:1.33138
# [28]	validation_0-rmse:1.30621
# [29]	validation_0-rmse:1.28315
# [30]	validation_0-rmse:1.26003
# [31]	validation_0-rmse:1.23884
# [32]	validation_0-rmse:1.21934
# [33]	validation_0-rmse:1.20167
# [34]	validation_0-rmse:1.18644
# [35]	validation_0-rmse:1.17273
# [36]	validation_0-rmse:1.15872
# [37]	validation_0-rmse:1.14590
# [38]	validation_0-rmse:1.13528
# [39]	validation_0-rmse:1.12452
# [40]	validation_0-rmse:1.11464
# [41]	validation_0-rmse:1.10562
# [42]	validation_0-rmse:1.09822
# [43]	validation_0-rmse:1.09073
# [44]	validation_0-rmse:1.08449
# [45]	validation_0-rmse:1.07883
# [46]	validation_0-rmse:1.07304
# [47]	validation_0-rmse:1.06774
# [48]	validation_0-rmse:1.06346
# [49]	validation_0-rmse:1.05904
# [50]	validation_0-rmse:1.05507
# [51]	validation_0-rmse:1.05139
# [52]	validation_0-rmse:1.04799
# [53]	validation_0-rmse:1.04497
# [54]	validation_0-rmse:1.04221
# [55]	validation_0-rmse:1.03976
# [56]	validation_0-rmse:1.03749
# [57]	validation_0-rmse:1.03560
# [58]	validation_0-rmse:1.03370
# [59]	validation_0-rmse:1.03195
# [60]	validation_0-rmse:1.03055
# [61]	validation_0-rmse:1.02912
# [62]	validation_0-rmse:1.02785
# [63]	validation_0-rmse:1.02658
# [64]	validation_0-rmse:1.02549
# [65]	validation_0-rmse:1.02449
# [66]	validation_0-rmse:1.02353
# [67]	validation_0-rmse:1.02268
# [68]	validation_0-rmse:1.02192
# [69]	validation_0-rmse:1.02112
# [70]	validation_0-rmse:1.02052
# [71]	validation_0-rmse:1.01994
# [72]	validation_0-rmse:1.01944
# [73]	validation_0-rmse:1.01897
# [74]	validation_0-rmse:1.01847
# [75]	validation_0-rmse:1.01802
# [76]	validation_0-rmse:1.01764
# [77]	validation_0-rmse:1.01722
# [78]	validation_0-rmse:1.01692
# [79]	validation_0-rmse:1.01658
# [80]	validation_0-rmse:1.01630
# [81]	validation_0-rmse:1.01604
# [82]	validation_0-rmse:1.01576
# [83]	validation_0-rmse:1.01548
# [84]	validation_0-rmse:1.01519
# [85]	validation_0-rmse:1.01489
# [86]	validation_0-rmse:1.01465
# [87]	validation_0-rmse:1.01448
# [88]	validation_0-rmse:1.01425
# [89]	validation_0-rmse:1.01409
# [90]	validation_0-rmse:1.01389
# [91]	validation_0-rmse:1.01372
# [92]	validation_0-rmse:1.01355
# [93]	validation_0-rmse:1.01333
# [94]	validation_0-rmse:1.01323
# [95]	validation_0-rmse:1.01312
# [96]	validation_0-rmse:1.01300
# [97]	validation_0-rmse:1.01290
# [98]	validation_0-rmse:1.01276
# [99]	validation_0-rmse:1.01272
# [100]	validation_0-rmse:1.01262
# [101]	validation_0-rmse:1.01249
# [102]	validation_0-rmse:1.01243
# [103]	validation_0-rmse:1.01236
# [104]	validation_0-rmse:1.01230
# [105]	validation_0-rmse:1.01219
# [106]	validation_0-rmse:1.01197
# [107]	validation_0-rmse:1.01189
# [108]	validation_0-rmse:1.01166
# [109]	validation_0-rmse:1.01158
# [110]	validation_0-rmse:1.01131
# [111]	validation_0-rmse:1.01120
# [112]	validation_0-rmse:1.01102
# [113]	validation_0-rmse:1.01092
# [114]	validation_0-rmse:1.01086
# [115]	validation_0-rmse:1.01078
# [116]	validation_0-rmse:1.01062
# [117]	validation_0-rmse:1.01039
# [118]	validation_0-rmse:1.01027
# [119]	validation_0-rmse:1.01022
# [120]	validation_0-rmse:1.01015
# [121]	validation_0-rmse:1.01008
# [122]	validation_0-rmse:1.01006
# [123]	validation_0-rmse:1.00997
# [124]	validation_0-rmse:1.00986
# [125]	validation_0-rmse:1.00982
# [126]	validation_0-rmse:1.00971
# [127]	validation_0-rmse:1.00964
# [128]	validation_0-rmse:1.00950
# [129]	validation_0-rmse:1.00936
# [130]	validation_0-rmse:1.00933
# [131]	validation_0-rmse:1.00918
# [132]	validation_0-rmse:1.00907
# [133]	validation_0-rmse:1.00900
# [134]	validation_0-rmse:1.00892
# [135]	validation_0-rmse:1.00872
# [136]	validation_0-rmse:1.00869
# [137]	validation_0-rmse:1.00854
# [138]	validation_0-rmse:1.00832
# [139]	validation_0-rmse:1.00832
# [140]	validation_0-rmse:1.00829
# [141]	validation_0-rmse:1.00819
# [142]	validation_0-rmse:1.00810
# [143]	validation_0-rmse:1.00798
# [144]	validation_0-rmse:1.00787
# [145]	validation_0-rmse:1.00785
# [146]	validation_0-rmse:1.00781
# [147]	validation_0-rmse:1.00780
# [148]	validation_0-rmse:1.00756
# [149]	validation_0-rmse:1.00729
# [150]	validation_0-rmse:1.00715
# [151]	validation_0-rmse:1.00715
# [152]	validation_0-rmse:1.00711
# [153]	validation_0-rmse:1.00707
# [154]	validation_0-rmse:1.00699
# [155]	validation_0-rmse:1.00687
# [156]	validation_0-rmse:1.00685
# [157]	validation_0-rmse:1.00680
# [158]	validation_0-rmse:1.00661
# [159]	validation_0-rmse:1.00657
# [160]	validation_0-rmse:1.00650
# [161]	validation_0-rmse:1.00632
# [162]	validation_0-rmse:1.00629
# [163]	validation_0-rmse:1.00613
# [164]	validation_0-rmse:1.00607
# [165]	validation_0-rmse:1.00607
# [166]	validation_0-rmse:1.00599
# [167]	validation_0-rmse:1.00590
# [168]	validation_0-rmse:1.00579
# [169]	validation_0-rmse:1.00577
# [170]	validation_0-rmse:1.00573
# [171]	validation_0-rmse:1.00562
# [172]	validation_0-rmse:1.00561
# [173]	validation_0-rmse:1.00559
# [174]	validation_0-rmse:1.00552
# [175]	validation_0-rmse:1.00542
# [176]	validation_0-rmse:1.00540
# [177]	validation_0-rmse:1.00531
# [178]	validation_0-rmse:1.00523
# [179]	validation_0-rmse:1.00521
# [180]	validation_0-rmse:1.00516
# [181]	validation_0-rmse:1.00512
# [182]	validation_0-rmse:1.00507
# [183]	validation_0-rmse:1.00502
# [184]	validation_0-rmse:1.00493
# [185]	validation_0-rmse:1.00492
# [186]	validation_0-rmse:1.00488
# [187]	validation_0-rmse:1.00487
# [188]	validation_0-rmse:1.00486
# [189]	validation_0-rmse:1.00477
# [190]	validation_0-rmse:1.00473
# [191]	validation_0-rmse:1.00469
# [192]	validation_0-rmse:1.00464
# [193]	validation_0-rmse:1.00454
# [194]	validation_0-rmse:1.00453
# [195]	validation_0-rmse:1.00437
# [196]	validation_0-rmse:1.00433
# [197]	validation_0-rmse:1.00431
# [198]	validation_0-rmse:1.00425
# [199]	validation_0-rmse:1.00423
# [200]	validation_0-rmse:1.00421
# [201]	validation_0-rmse:1.00421
# [202]	validation_0-rmse:1.00417
# [203]	validation_0-rmse:1.00406
# [204]	validation_0-rmse:1.00399
# [205]	validation_0-rmse:1.00398
# [206]	validation_0-rmse:1.00395
# [207]	validation_0-rmse:1.00395
# [208]	validation_0-rmse:1.00385
# [209]	validation_0-rmse:1.00379
# [210]	validation_0-rmse:1.00371
# [211]	validation_0-rmse:1.00360
# [212]	validation_0-rmse:1.00356
# [213]	validation_0-rmse:1.00353
# [214]	validation_0-rmse:1.00351
# [215]	validation_0-rmse:1.00349
# [216]	validation_0-rmse:1.00349
# [217]	validation_0-rmse:1.00345
# [218]	validation_0-rmse:1.00341
# [219]	validation_0-rmse:1.00338
# [220]	validation_0-rmse:1.00331
# [221]	validation_0-rmse:1.00331
# [222]	validation_0-rmse:1.00329
# [223]	validation_0-rmse:1.00314
# [224]	validation_0-rmse:1.00311
# [225]	validation_0-rmse:1.00307
# [226]	validation_0-rmse:1.00300
# [227]	validation_0-rmse:1.00299
# [228]	validation_0-rmse:1.00292
# [229]	validation_0-rmse:1.00290
# [230]	validation_0-rmse:1.00287
# [231]	validation_0-rmse:1.00279
# [232]	validation_0-rmse:1.00277
# [233]	validation_0-rmse:1.00278
# [234]	validation_0-rmse:1.00277
# [235]	validation_0-rmse:1.00270
# [236]	validation_0-rmse:1.00259
# [237]	validation_0-rmse:1.00252
# [238]	validation_0-rmse:1.00249
# [239]	validation_0-rmse:1.00244
# [240]	validation_0-rmse:1.00242
# [241]	validation_0-rmse:1.00237
# [242]	validation_0-rmse:1.00236
# [243]	validation_0-rmse:1.00235
# [244]	validation_0-rmse:1.00232
# [245]	validation_0-rmse:1.00231
# [246]	validation_0-rmse:1.00224
# [247]	validation_0-rmse:1.00216
# [248]	validation_0-rmse:1.00208
# [249]	validation_0-rmse:1.00203
# [250]	validation_0-rmse:1.00202
# [251]	validation_0-rmse:1.00197
# [252]	validation_0-rmse:1.00193
# [253]	validation_0-rmse:1.00192
# [254]	validation_0-rmse:1.00186
# [255]	validation_0-rmse:1.00184
# [256]	validation_0-rmse:1.00185
# [257]	validation_0-rmse:1.00177
# [258]	validation_0-rmse:1.00161
# [259]	validation_0-rmse:1.00160
# [260]	validation_0-rmse:1.00162
# [261]	validation_0-rmse:1.00160
# [262]	validation_0-rmse:1.00157
# [263]	validation_0-rmse:1.00155
# [264]	validation_0-rmse:1.00157
# [265]	validation_0-rmse:1.00154
# [266]	validation_0-rmse:1.00149
# [267]	validation_0-rmse:1.00146
# [268]	validation_0-rmse:1.00134
# [269]	validation_0-rmse:1.00125
# [270]	validation_0-rmse:1.00125
# [271]	validation_0-rmse:1.00118
# [272]	validation_0-rmse:1.00110
# [273]	validation_0-rmse:1.00107
# [274]	validation_0-rmse:1.00107
# [275]	validation_0-rmse:1.00104
# [276]	validation_0-rmse:1.00098
# [277]	validation_0-rmse:1.00085
# [278]	validation_0-rmse:1.00084
# [279]	validation_0-rmse:1.00083
# [280]	validation_0-rmse:1.00084
# [281]	validation_0-rmse:1.00080
# [282]	validation_0-rmse:1.00066
# [283]	validation_0-rmse:1.00056
# [284]	validation_0-rmse:1.00049
# [285]	validation_0-rmse:1.00045
# [286]	validation_0-rmse:1.00046
# [287]	validation_0-rmse:1.00046
# [288]	validation_0-rmse:1.00046
# [289]	validation_0-rmse:1.00039
# [290]	validation_0-rmse:1.00025
# [291]	validation_0-rmse:1.00017
# [292]	validation_0-rmse:1.00016
# [293]	validation_0-rmse:1.00015
# [294]	validation_0-rmse:1.00013
# [295]	validation_0-rmse:1.00009
# [296]	validation_0-rmse:1.00005
# [297]	validation_0-rmse:1.00001
# [298]	validation_0-rmse:0.99997
# [299]	validation_0-rmse:0.99994
# [300]	validation_0-rmse:0.99990
# [301]	validation_0-rmse:0.99990
# [302]	validation_0-rmse:0.99991
# [303]	validation_0-rmse:0.99985
# [304]	validation_0-rmse:0.99984
# [305]	validation_0-rmse:0.99979
# [306]	validation_0-rmse:0.99980
# [307]	validation_0-rmse:0.99977
# [308]	validation_0-rmse:0.99973
# [309]	validation_0-rmse:0.99971
# [310]	validation_0-rmse:0.99965
# [311]	validation_0-rmse:0.99959
# [312]	validation_0-rmse:0.99956
# [313]	validation_0-rmse:0.99952
# [314]	validation_0-rmse:0.99949
# [315]	validation_0-rmse:0.99946
# [316]	validation_0-rmse:0.99940
# [317]	validation_0-rmse:0.99938
# [318]	validation_0-rmse:0.99936
# [319]	validation_0-rmse:0.99936
# [320]	validation_0-rmse:0.99931
# [321]	validation_0-rmse:0.99927
# [322]	validation_0-rmse:0.99918
# [323]	validation_0-rmse:0.99909
# [324]	validation_0-rmse:0.99908
# [325]	validation_0-rmse:0.99907
# [326]	validation_0-rmse:0.99904
# [327]	validation_0-rmse:0.99905
# [328]	validation_0-rmse:0.99897
# [329]	validation_0-rmse:0.99898
# [330]	validation_0-rmse:0.99898
# [331]	validation_0-rmse:0.99891
# [332]	validation_0-rmse:0.99891
# [333]	validation_0-rmse:0.99891
# [334]	validation_0-rmse:0.99891
# [335]	validation_0-rmse:0.99883
# [336]	validation_0-rmse:0.99876
# [337]	validation_0-rmse:0.99875
# [338]	validation_0-rmse:0.99871
# [339]	validation_0-rmse:0.99864
# [340]	validation_0-rmse:0.99865
# [341]	validation_0-rmse:0.99867
# [342]	validation_0-rmse:0.99855
# [343]	validation_0-rmse:0.99853
# [344]	validation_0-rmse:0.99851
# [345]	validation_0-rmse:0.99850
# [346]	validation_0-rmse:0.99846
# [347]	validation_0-rmse:0.99846
# [348]	validation_0-rmse:0.99843
# [349]	validation_0-rmse:0.99841
# [350]	validation_0-rmse:0.99842
# [351]	validation_0-rmse:0.99840
# [352]	validation_0-rmse:0.99839
# [353]	validation_0-rmse:0.99839
# [354]	validation_0-rmse:0.99838
# [355]	validation_0-rmse:0.99836
# [356]	validation_0-rmse:0.99835
# [357]	validation_0-rmse:0.99837
# [358]	validation_0-rmse:0.99829
# [359]	validation_0-rmse:0.99826
# [360]	validation_0-rmse:0.99824
# [361]	validation_0-rmse:0.99824
# [362]	validation_0-rmse:0.99825
# [363]	validation_0-rmse:0.99822
# [364]	validation_0-rmse:0.99819
# [365]	validation_0-rmse:0.99817
# [366]	validation_0-rmse:0.99809
# [367]	validation_0-rmse:0.99806
# [368]	validation_0-rmse:0.99806
# [369]	validation_0-rmse:0.99805
# [370]	validation_0-rmse:0.99808
# [371]	validation_0-rmse:0.99807
# [372]	validation_0-rmse:0.99805
# [373]	validation_0-rmse:0.99802
# [374]	validation_0-rmse:0.99799
# [375]	validation_0-rmse:0.99801
# [376]	validation_0-rmse:0.99800
# [377]	validation_0-rmse:0.99806
# [378]	validation_0-rmse:0.99804
# [379]	validation_0-rmse:0.99803
# [380]	validation_0-rmse:0.99803
# [381]	validation_0-rmse:0.99802
# [382]	validation_0-rmse:0.99801
# [383]	validation_0-rmse:0.99796
# [384]	validation_0-rmse:0.99792
# [385]	validation_0-rmse:0.99793
# [386]	validation_0-rmse:0.99791
# [387]	validation_0-rmse:0.99792
# [388]	validation_0-rmse:0.99788
# [389]	validation_0-rmse:0.99783
# [390]	validation_0-rmse:0.99782
# [391]	validation_0-rmse:0.99775
# [392]	validation_0-rmse:0.99773
# [393]	validation_0-rmse:0.99772
# [394]	validation_0-rmse:0.99769
# [395]	validation_0-rmse:0.99769
# [396]	validation_0-rmse:0.99761
# [397]	validation_0-rmse:0.99761
# [398]	validation_0-rmse:0.99754
# [399]	validation_0-rmse:0.99753
# [400]	validation_0-rmse:0.99748
# [401]	validation_0-rmse:0.99748
# [402]	validation_0-rmse:0.99747
# [403]	validation_0-rmse:0.99743
# [404]	validation_0-rmse:0.99742
# [405]	validation_0-rmse:0.99743
# [406]	validation_0-rmse:0.99739
# [407]	validation_0-rmse:0.99737
# [408]	validation_0-rmse:0.99734
# [409]	validation_0-rmse:0.99734
# [410]	validation_0-rmse:0.99732
# [411]	validation_0-rmse:0.99725
# [412]	validation_0-rmse:0.99724
# [413]	validation_0-rmse:0.99722
# [414]	validation_0-rmse:0.99719
# [415]	validation_0-rmse:0.99717
# [416]	validation_0-rmse:0.99711
# [417]	validation_0-rmse:0.99706
# [418]	validation_0-rmse:0.99704
# [419]	validation_0-rmse:0.99703
# [420]	validation_0-rmse:0.99700
# [421]	validation_0-rmse:0.99700
# [422]	validation_0-rmse:0.99696
# [423]	validation_0-rmse:0.99692
# [424]	validation_0-rmse:0.99691
# [425]	validation_0-rmse:0.99691
# [426]	validation_0-rmse:0.99690
# [427]	validation_0-rmse:0.99685
# [428]	validation_0-rmse:0.99683
# [429]	validation_0-rmse:0.99681
# [430]	validation_0-rmse:0.99681
# [431]	validation_0-rmse:0.99679
# [432]	validation_0-rmse:0.99668
# [433]	validation_0-rmse:0.99670
# [434]	validation_0-rmse:0.99668
# [435]	validation_0-rmse:0.99666
# [436]	validation_0-rmse:0.99663
# [437]	validation_0-rmse:0.99662
# [438]	validation_0-rmse:0.99662
# [439]	validation_0-rmse:0.99659
# [440]	validation_0-rmse:0.99656
# [441]	validation_0-rmse:0.99654
# [442]	validation_0-rmse:0.99648
# [443]	validation_0-rmse:0.99644
# [444]	validation_0-rmse:0.99640
# [445]	validation_0-rmse:0.99640
# [446]	validation_0-rmse:0.99636
# [447]	validation_0-rmse:0.99631
# [448]	validation_0-rmse:0.99630
# [449]	validation_0-rmse:0.99629
# [450]	validation_0-rmse:0.99628
# [451]	validation_0-rmse:0.99623
# [452]	validation_0-rmse:0.99618
# [453]	validation_0-rmse:0.99617
# [454]	validation_0-rmse:0.99613
# [455]	validation_0-rmse:0.99611
# [456]	validation_0-rmse:0.99609
# [457]	validation_0-rmse:0.99610
# [458]	validation_0-rmse:0.99610
# [459]	validation_0-rmse:0.99610
# [460]	validation_0-rmse:0.99606
# [461]	validation_0-rmse:0.99604
# [462]	validation_0-rmse:0.99599
# [463]	validation_0-rmse:0.99598
# [464]	validation_0-rmse:0.99590
# [465]	validation_0-rmse:0.99585
# [466]	validation_0-rmse:0.99583
# [467]	validation_0-rmse:0.99584
# [468]	validation_0-rmse:0.99584
# [469]	validation_0-rmse:0.99582
# [470]	validation_0-rmse:0.99582
# [471]	validation_0-rmse:0.99583
# [472]	validation_0-rmse:0.99586
# [473]	validation_0-rmse:0.99583
# [474]	validation_0-rmse:0.99581
# [475]	validation_0-rmse:0.99578
# [476]	validation_0-rmse:0.99577
# [477]	validation_0-rmse:0.99575
# [478]	validation_0-rmse:0.99574
# [479]	validation_0-rmse:0.99571
# [480]	validation_0-rmse:0.99565
# [481]	validation_0-rmse:0.99563
# [482]	validation_0-rmse:0.99558
# [483]	validation_0-rmse:0.99559
# [484]	validation_0-rmse:0.99557
# [485]	validation_0-rmse:0.99558
# [486]	validation_0-rmse:0.99559
# [487]	validation_0-rmse:0.99559
# [488]	validation_0-rmse:0.99558
# [489]	validation_0-rmse:0.99556
# [490]	validation_0-rmse:0.99557
# [491]	validation_0-rmse:0.99556
# [492]	validation_0-rmse:0.99553
# [493]	validation_0-rmse:0.99551
# [494]	validation_0-rmse:0.99553
# [495]	validation_0-rmse:0.99549
# [496]	validation_0-rmse:0.99551
# [497]	validation_0-rmse:0.99550
# [498]	validation_0-rmse:0.99549
# [499]	validation_0-rmse:0.99549
# [500]	validation_0-rmse:0.99550
# [501]	validation_0-rmse:0.99551
# [502]	validation_0-rmse:0.99549
# [503]	validation_0-rmse:0.99544
# [504]	validation_0-rmse:0.99539
# [505]	validation_0-rmse:0.99534
# [506]	validation_0-rmse:0.99534
# [507]	validation_0-rmse:0.99529
# [508]	validation_0-rmse:0.99527
# [509]	validation_0-rmse:0.99526
# [510]	validation_0-rmse:0.99520
# [511]	validation_0-rmse:0.99522
# [512]	validation_0-rmse:0.99521
# [513]	validation_0-rmse:0.99521
# [514]	validation_0-rmse:0.99515
# [515]	validation_0-rmse:0.99516
# [516]	validation_0-rmse:0.99513
# [517]	validation_0-rmse:0.99510
# [518]	validation_0-rmse:0.99507
# [519]	validation_0-rmse:0.99506
# [520]	validation_0-rmse:0.99506
# [521]	validation_0-rmse:0.99503
# [522]	validation_0-rmse:0.99502
# [523]	validation_0-rmse:0.99502
# [524]	validation_0-rmse:0.99502
# [525]	validation_0-rmse:0.99502
# [526]	validation_0-rmse:0.99498
# [527]	validation_0-rmse:0.99497
# [528]	validation_0-rmse:0.99496
# [529]	validation_0-rmse:0.99494
# [530]	validation_0-rmse:0.99492
# [531]	validation_0-rmse:0.99489
# [532]	validation_0-rmse:0.99488
# [533]	validation_0-rmse:0.99487
# [534]	validation_0-rmse:0.99481
# [535]	validation_0-rmse:0.99480
# [536]	validation_0-rmse:0.99477
# [537]	validation_0-rmse:0.99471
# [538]	validation_0-rmse:0.99472
# [539]	validation_0-rmse:0.99473
# [540]	validation_0-rmse:0.99475
# [541]	validation_0-rmse:0.99474
# [542]	validation_0-rmse:0.99472
# [543]	validation_0-rmse:0.99469
# [544]	validation_0-rmse:0.99468
# [545]	validation_0-rmse:0.99463
# [546]	validation_0-rmse:0.99463
# [547]	validation_0-rmse:0.99463
# [548]	validation_0-rmse:0.99460
# [549]	validation_0-rmse:0.99459
# [550]	validation_0-rmse:0.99459
# [551]	validation_0-rmse:0.99454
# [552]	validation_0-rmse:0.99453
# [553]	validation_0-rmse:0.99452
# [554]	validation_0-rmse:0.99451
# [555]	validation_0-rmse:0.99448
# [556]	validation_0-rmse:0.99442
# [557]	validation_0-rmse:0.99436
# [558]	validation_0-rmse:0.99436
# [559]	validation_0-rmse:0.99432
# [560]	validation_0-rmse:0.99432
# [561]	validation_0-rmse:0.99431
# [562]	validation_0-rmse:0.99429
# [563]	validation_0-rmse:0.99425
# [564]	validation_0-rmse:0.99424
# [565]	validation_0-rmse:0.99422
# [566]	validation_0-rmse:0.99420
# [567]	validation_0-rmse:0.99420
# [568]	validation_0-rmse:0.99416
# [569]	validation_0-rmse:0.99414
# [570]	validation_0-rmse:0.99412
# [571]	validation_0-rmse:0.99411
# [572]	validation_0-rmse:0.99411
# [573]	validation_0-rmse:0.99408
# [574]	validation_0-rmse:0.99409
# [575]	validation_0-rmse:0.99402
# [576]	validation_0-rmse:0.99403
# [577]	validation_0-rmse:0.99401
# [578]	validation_0-rmse:0.99402
# [579]	validation_0-rmse:0.99400
# [580]	validation_0-rmse:0.99392
# [581]	validation_0-rmse:0.99389
# [582]	validation_0-rmse:0.99389
# [583]	validation_0-rmse:0.99388
# [584]	validation_0-rmse:0.99386
# [585]	validation_0-rmse:0.99387
# [586]	validation_0-rmse:0.99386
# [587]	validation_0-rmse:0.99385
# [588]	validation_0-rmse:0.99381
# [589]	validation_0-rmse:0.99383
# [590]	validation_0-rmse:0.99381
# [591]	validation_0-rmse:0.99381
# [592]	validation_0-rmse:0.99380
# [593]	validation_0-rmse:0.99381
# [594]	validation_0-rmse:0.99378
# [595]	validation_0-rmse:0.99376
# [596]	validation_0-rmse:0.99373
# [597]	validation_0-rmse:0.99372
# [598]	validation_0-rmse:0.99372
# [599]	validation_0-rmse:0.99373
# [600]	validation_0-rmse:0.99370
# [601]	validation_0-rmse:0.99370
# [602]	validation_0-rmse:0.99370
# [603]	validation_0-rmse:0.99369
# [604]	validation_0-rmse:0.99368
# [605]	validation_0-rmse:0.99362
# [606]	validation_0-rmse:0.99355
# [607]	validation_0-rmse:0.99356
# [608]	validation_0-rmse:0.99356
# [609]	validation_0-rmse:0.99355
# [610]	validation_0-rmse:0.99351
# [611]	validation_0-rmse:0.99347
# [612]	validation_0-rmse:0.99337
# [613]	validation_0-rmse:0.99337
# [614]	validation_0-rmse:0.99334
# [615]	validation_0-rmse:0.99335
# [616]	validation_0-rmse:0.99335
# [617]	validation_0-rmse:0.99336
# [618]	validation_0-rmse:0.99333
# [619]	validation_0-rmse:0.99328
# [620]	validation_0-rmse:0.99328
# [621]	validation_0-rmse:0.99330
# [622]	validation_0-rmse:0.99329
# [623]	validation_0-rmse:0.99327
# [624]	validation_0-rmse:0.99328
# [625]	validation_0-rmse:0.99323
# [626]	validation_0-rmse:0.99319
# [627]	validation_0-rmse:0.99318
# [628]	validation_0-rmse:0.99315
# [629]	validation_0-rmse:0.99314
# [630]	validation_0-rmse:0.99315
# [631]	validation_0-rmse:0.99315
# [632]	validation_0-rmse:0.99309
# [633]	validation_0-rmse:0.99306
# [634]	validation_0-rmse:0.99303
# [635]	validation_0-rmse:0.99303
# [636]	validation_0-rmse:0.99301
# [637]	validation_0-rmse:0.99303
# [638]	validation_0-rmse:0.99299
# [639]	validation_0-rmse:0.99296
# [640]	validation_0-rmse:0.99294
# [641]	validation_0-rmse:0.99294
# [642]	validation_0-rmse:0.99294
# [643]	validation_0-rmse:0.99291
# [644]	validation_0-rmse:0.99288
# [645]	validation_0-rmse:0.99284
# [646]	validation_0-rmse:0.99282
# [647]	validation_0-rmse:0.99281
# [648]	validation_0-rmse:0.99278
# [649]	validation_0-rmse:0.99277
# [650]	validation_0-rmse:0.99278
# [651]	validation_0-rmse:0.99273
# [652]	validation_0-rmse:0.99276
# [653]	validation_0-rmse:0.99278
# [654]	validation_0-rmse:0.99276
# [655]	validation_0-rmse:0.99277
# [656]	validation_0-rmse:0.99280
# [657]	validation_0-rmse:0.99278
# [658]	validation_0-rmse:0.99278
# [659]	validation_0-rmse:0.99278
# [660]	validation_0-rmse:0.99279
# [661]	validation_0-rmse:0.99280
# [662]	validation_0-rmse:0.99279
# [663]	validation_0-rmse:0.99278
# [664]	validation_0-rmse:0.99277
# [665]	validation_0-rmse:0.99277
# [666]	validation_0-rmse:0.99276
# [667]	validation_0-rmse:0.99273
# [668]	validation_0-rmse:0.99274
# [669]	validation_0-rmse:0.99275
# [670]	validation_0-rmse:0.99273
# [671]	validation_0-rmse:0.99273
# [672]	validation_0-rmse:0.99274
# [673]	validation_0-rmse:0.99274
# [674]	validation_0-rmse:0.99270
# [675]	validation_0-rmse:0.99269
# [676]	validation_0-rmse:0.99269
# [677]	validation_0-rmse:0.99263
# [678]	validation_0-rmse:0.99262
# [679]	validation_0-rmse:0.99264
# [680]	validation_0-rmse:0.99264
# [681]	validation_0-rmse:0.99263
# [682]	validation_0-rmse:0.99260
# [683]	validation_0-rmse:0.99259
# [684]	validation_0-rmse:0.99257
# [685]	validation_0-rmse:0.99258
# [686]	validation_0-rmse:0.99257
# [687]	validation_0-rmse:0.99259
# [688]	validation_0-rmse:0.99257
# [689]	validation_0-rmse:0.99258
# [690]	validation_0-rmse:0.99259
# [691]	validation_0-rmse:0.99251
# [692]	validation_0-rmse:0.99253
# [693]	validation_0-rmse:0.99255
# [694]	validation_0-rmse:0.99253
# [695]	validation_0-rmse:0.99256
# [696]	validation_0-rmse:0.99255
# [697]	validation_0-rmse:0.99255
# [698]	validation_0-rmse:0.99251
# [699]	validation_0-rmse:0.99250
# [700]	validation_0-rmse:0.99249
# [701]	validation_0-rmse:0.99245
# [702]	validation_0-rmse:0.99245
# [703]	validation_0-rmse:0.99243
# [704]	validation_0-rmse:0.99242
# [705]	validation_0-rmse:0.99240
# [706]	validation_0-rmse:0.99236
# [707]	validation_0-rmse:0.99237
# [708]	validation_0-rmse:0.99239
# [709]	validation_0-rmse:0.99239
# [710]	validation_0-rmse:0.99238
# [711]	validation_0-rmse:0.99235
# [712]	validation_0-rmse:0.99233
# [713]	validation_0-rmse:0.99232
# [714]	validation_0-rmse:0.99231
# [715]	validation_0-rmse:0.99230
# [716]	validation_0-rmse:0.99227
# [717]	validation_0-rmse:0.99228
# [718]	validation_0-rmse:0.99230
# [719]	validation_0-rmse:0.99230
# [720]	validation_0-rmse:0.99229
# [721]	validation_0-rmse:0.99229
# [722]	validation_0-rmse:0.99227
# [723]	validation_0-rmse:0.99225
# [724]	validation_0-rmse:0.99225
# [725]	validation_0-rmse:0.99225
# [726]	validation_0-rmse:0.99224
# [727]	validation_0-rmse:0.99224
# [728]	validation_0-rmse:0.99223
# [729]	validation_0-rmse:0.99222
# [730]	validation_0-rmse:0.99223
# [731]	validation_0-rmse:0.99219
# [732]	validation_0-rmse:0.99218
# [733]	validation_0-rmse:0.99220
# [734]	validation_0-rmse:0.99218
# [735]	validation_0-rmse:0.99217
# [736]	validation_0-rmse:0.99215
# [737]	validation_0-rmse:0.99213
# [738]	validation_0-rmse:0.99212
# [739]	validation_0-rmse:0.99211
# [740]	validation_0-rmse:0.99209
# [741]	validation_0-rmse:0.99206
# [742]	validation_0-rmse:0.99206
# [743]	validation_0-rmse:0.99206
# [744]	validation_0-rmse:0.99205
# [745]	validation_0-rmse:0.99203
# [746]	validation_0-rmse:0.99203
# [747]	validation_0-rmse:0.99204
# [748]	validation_0-rmse:0.99202
# [749]	validation_0-rmse:0.99203
# [750]	validation_0-rmse:0.99202
# [751]	validation_0-rmse:0.99202
# [752]	validation_0-rmse:0.99201
# [753]	validation_0-rmse:0.99197
# [754]	validation_0-rmse:0.99199
# [755]	validation_0-rmse:0.99199
# [756]	validation_0-rmse:0.99199
# [757]	validation_0-rmse:0.99196
# [758]	validation_0-rmse:0.99197
# [759]	validation_0-rmse:0.99197
# [760]	validation_0-rmse:0.99189
# [761]	validation_0-rmse:0.99182
# [762]	validation_0-rmse:0.99179
# [763]	validation_0-rmse:0.99174
# [764]	validation_0-rmse:0.99175
# [765]	validation_0-rmse:0.99173
# [766]	validation_0-rmse:0.99173
# [767]	validation_0-rmse:0.99170
# [768]	validation_0-rmse:0.99170
# [769]	validation_0-rmse:0.99170
# [770]	validation_0-rmse:0.99168
# [771]	validation_0-rmse:0.99168
# [772]	validation_0-rmse:0.99168
# [773]	validation_0-rmse:0.99168
# [774]	validation_0-rmse:0.99166
# [775]	validation_0-rmse:0.99164
# [776]	validation_0-rmse:0.99166
# [777]	validation_0-rmse:0.99165
# [778]	validation_0-rmse:0.99166
# [779]	validation_0-rmse:0.99164
# [780]	validation_0-rmse:0.99161
# [781]	validation_0-rmse:0.99162
# [782]	validation_0-rmse:0.99161
# [783]	validation_0-rmse:0.99160
# [784]	validation_0-rmse:0.99159
# [785]	validation_0-rmse:0.99154
# [786]	validation_0-rmse:0.99151
# [787]	validation_0-rmse:0.99150
# [788]	validation_0-rmse:0.99146
# [789]	validation_0-rmse:0.99148
# [790]	validation_0-rmse:0.99147
# [791]	validation_0-rmse:0.99144
# [792]	validation_0-rmse:0.99142
# [793]	validation_0-rmse:0.99142
# [794]	validation_0-rmse:0.99143
# [795]	validation_0-rmse:0.99140
# [796]	validation_0-rmse:0.99140
# [797]	validation_0-rmse:0.99140
# [798]	validation_0-rmse:0.99138
# [799]	validation_0-rmse:0.99137
# [800]	validation_0-rmse:0.99136
# [801]	validation_0-rmse:0.99134
# [802]	validation_0-rmse:0.99131
# [803]	validation_0-rmse:0.99131
# [804]	validation_0-rmse:0.99131
# [805]	validation_0-rmse:0.99129
# [806]	validation_0-rmse:0.99125
# [807]	validation_0-rmse:0.99125
# [808]	validation_0-rmse:0.99121
# [809]	validation_0-rmse:0.99122
# [810]	validation_0-rmse:0.99119
# [811]	validation_0-rmse:0.99117
# [812]	validation_0-rmse:0.99119
# [813]	validation_0-rmse:0.99119
# [814]	validation_0-rmse:0.99117
# [815]	validation_0-rmse:0.99114
# [816]	validation_0-rmse:0.99115
# [817]	validation_0-rmse:0.99113
# [818]	validation_0-rmse:0.99114
# [819]	validation_0-rmse:0.99113
# [820]	validation_0-rmse:0.99113
# [821]	validation_0-rmse:0.99111
# [822]	validation_0-rmse:0.99109
# [823]	validation_0-rmse:0.99108
# [824]	validation_0-rmse:0.99104
# [825]	validation_0-rmse:0.99103
# [826]	validation_0-rmse:0.99102
# [827]	validation_0-rmse:0.99100
# [828]	validation_0-rmse:0.99099
# [829]	validation_0-rmse:0.99100
# [830]	validation_0-rmse:0.99102
# [831]	validation_0-rmse:0.99102
# [832]	validation_0-rmse:0.99101
# [833]	validation_0-rmse:0.99099
# [834]	validation_0-rmse:0.99097
# [835]	validation_0-rmse:0.99098
# [836]	validation_0-rmse:0.99101
# [837]	validation_0-rmse:0.99101
# [838]	validation_0-rmse:0.99099
# [839]	validation_0-rmse:0.99096
# [840]	validation_0-rmse:0.99095
# [841]	validation_0-rmse:0.99097
# [842]	validation_0-rmse:0.99097
# [843]	validation_0-rmse:0.99097
# [844]	validation_0-rmse:0.99094
# [845]	validation_0-rmse:0.99094
# [846]	validation_0-rmse:0.99094
# [847]	validation_0-rmse:0.99094
# [848]	validation_0-rmse:0.99095
# [849]	validation_0-rmse:0.99094
# [850]	validation_0-rmse:0.99091
# [851]	validation_0-rmse:0.99091
# [852]	validation_0-rmse:0.99091
# [853]	validation_0-rmse:0.99090
# [854]	validation_0-rmse:0.99090
# [855]	validation_0-rmse:0.99089
# [856]	validation_0-rmse:0.99089
# [857]	validation_0-rmse:0.99087
# [858]	validation_0-rmse:0.99087
# [859]	validation_0-rmse:0.99082
# [860]	validation_0-rmse:0.99082
# [861]	validation_0-rmse:0.99081
# [862]	validation_0-rmse:0.99081
# [863]	validation_0-rmse:0.99081
# [864]	validation_0-rmse:0.99080
# [865]	validation_0-rmse:0.99080
# [866]	validation_0-rmse:0.99082
# [867]	validation_0-rmse:0.99081
# [868]	validation_0-rmse:0.99080
# [869]	validation_0-rmse:0.99079
# [870]	validation_0-rmse:0.99078
# [871]	validation_0-rmse:0.99077
# [872]	validation_0-rmse:0.99078
# [873]	validation_0-rmse:0.99078
# [874]	validation_0-rmse:0.99076
# [875]	validation_0-rmse:0.99074
# [876]	validation_0-rmse:0.99075
# [877]	validation_0-rmse:0.99076
# [878]	validation_0-rmse:0.99075
# [879]	validation_0-rmse:0.99073
# [880]	validation_0-rmse:0.99071
# [881]	validation_0-rmse:0.99072
# [882]	validation_0-rmse:0.99071
# [883]	validation_0-rmse:0.99069
# [884]	validation_0-rmse:0.99069
# [885]	validation_0-rmse:0.99071
# [886]	validation_0-rmse:0.99071
# [887]	validation_0-rmse:0.99068
# [888]	validation_0-rmse:0.99068
# [889]	validation_0-rmse:0.99070
# [890]	validation_0-rmse:0.99070
# [891]	validation_0-rmse:0.99068
# [892]	validation_0-rmse:0.99068
# [893]	validation_0-rmse:0.99064
# [894]	validation_0-rmse:0.99061
# [895]	validation_0-rmse:0.99064
# [896]	validation_0-rmse:0.99066
# [897]	validation_0-rmse:0.99065
# [898]	validation_0-rmse:0.99064
# [899]	validation_0-rmse:0.99063
# [900]	validation_0-rmse:0.99063
# [901]	validation_0-rmse:0.99064
# [902]	validation_0-rmse:0.99065
# [903]	validation_0-rmse:0.99063
# [904]	validation_0-rmse:0.99063
# [905]	validation_0-rmse:0.99062
# [906]	validation_0-rmse:0.99061
# [907]	validation_0-rmse:0.99063
# [908]	validation_0-rmse:0.99061
# [909]	validation_0-rmse:0.99058
# [910]	validation_0-rmse:0.99059
# [911]	validation_0-rmse:0.99058
# [912]	validation_0-rmse:0.99059
# [913]	validation_0-rmse:0.99056
# [914]	validation_0-rmse:0.99055
# [915]	validation_0-rmse:0.99055
# [916]	validation_0-rmse:0.99053
# [917]	validation_0-rmse:0.99053
# [918]	validation_0-rmse:0.99053
# [919]	validation_0-rmse:0.99056
# [920]	validation_0-rmse:0.99056
# [921]	validation_0-rmse:0.99057
# [922]	validation_0-rmse:0.99059
# [923]	validation_0-rmse:0.99059
# [924]	validation_0-rmse:0.99053
# [925]	validation_0-rmse:0.99049
# [926]	validation_0-rmse:0.99048
# [927]	validation_0-rmse:0.99045
# [928]	validation_0-rmse:0.99044
# [929]	validation_0-rmse:0.99044
# [930]	validation_0-rmse:0.99042
# [931]	validation_0-rmse:0.99042
# [932]	validation_0-rmse:0.99044
# [933]	validation_0-rmse:0.99043
# [934]	validation_0-rmse:0.99044
# [935]	validation_0-rmse:0.99042
# [936]	validation_0-rmse:0.99041
# [937]	validation_0-rmse:0.99043
# [938]	validation_0-rmse:0.99044
# [939]	validation_0-rmse:0.99044
# [940]	validation_0-rmse:0.99044
# [941]	validation_0-rmse:0.99044
# [942]	validation_0-rmse:0.99044
# [943]	validation_0-rmse:0.99041
# [944]	validation_0-rmse:0.99037
# [945]	validation_0-rmse:0.99039
# [946]	validation_0-rmse:0.99037
# [947]	validation_0-rmse:0.99034
# [948]	validation_0-rmse:0.99031
# [949]	validation_0-rmse:0.99028
# [950]	validation_0-rmse:0.99031
# [951]	validation_0-rmse:0.99029
# [952]	validation_0-rmse:0.99028
# [953]	validation_0-rmse:0.99024
# [954]	validation_0-rmse:0.99019
# [955]	validation_0-rmse:0.99022
# [956]	validation_0-rmse:0.99021
# [957]	validation_0-rmse:0.99022
# [958]	validation_0-rmse:0.99020
# [959]	validation_0-rmse:0.99019
# [960]	validation_0-rmse:0.99018
# [961]	validation_0-rmse:0.99017
# [962]	validation_0-rmse:0.99016
# [963]	validation_0-rmse:0.99012
# [964]	validation_0-rmse:0.99010
# [965]	validation_0-rmse:0.99010
# [966]	validation_0-rmse:0.99010
# [967]	validation_0-rmse:0.99009
# [968]	validation_0-rmse:0.99008
# [969]	validation_0-rmse:0.99010
# [970]	validation_0-rmse:0.99009
# [971]	validation_0-rmse:0.99006
# [972]	validation_0-rmse:0.99007
# [973]	validation_0-rmse:0.99006
# [974]	validation_0-rmse:0.99005
# [975]	validation_0-rmse:0.99006
# [976]	validation_0-rmse:0.99005
# [977]	validation_0-rmse:0.99003
# [978]	validation_0-rmse:0.99002
# [979]	validation_0-rmse:0.99002
# [980]	validation_0-rmse:0.99002
# [981]	validation_0-rmse:0.99002
# [982]	validation_0-rmse:0.99003
# [983]	validation_0-rmse:0.99003
# [984]	validation_0-rmse:0.98999
# [985]	validation_0-rmse:0.98998
# [986]	validation_0-rmse:0.98996
# [987]	validation_0-rmse:0.98992
# [988]	validation_0-rmse:0.98990
# [989]	validation_0-rmse:0.98991
# [990]	validation_0-rmse:0.98993
# [991]	validation_0-rmse:0.98993
# [992]	validation_0-rmse:0.98989
# [993]	validation_0-rmse:0.98991
# [994]	validation_0-rmse:0.98988
# [995]	validation_0-rmse:0.98988
# [996]	validation_0-rmse:0.98989
# [997]	validation_0-rmse:0.98987
# [998]	validation_0-rmse:0.98988
# [999]	validation_0-rmse:0.98987
# XGBoost Validation Log MSE: 0.9800216427810836
# XGBoost Validation R²: 0.3519317271561272
# XGBoost Test Log MSE: 3.1723084765265406
# XGBoost Test R²: -0.023006178225395857
#
# Sample Predictions (XGB):
# Actual: 14, Predicted: 59
# Actual: 25, Predicted: 30
# Actual: 100, Predicted: 64
# Actual: 28, Predicted: 24
# Actual: 38, Predicted: 36
# Actual: 41, Predicted: 31
# Actual: 19, Predicted: 21
# Actual: 107, Predicted: 84
# Actual: 73, Predicted: 53
# Actual: 98, Predicted: 107

# %%
import json
import re
import numpy as np
from datetime import datetime

# Path to your new file with 3000 lines
test_file_path = "test-regression-round2.jsonl"

# Output file path
output_file_path = "prediction-regression-round2.json"

# Dictionary to store predictions: { post_id: predicted_like_count }
predictions_dict = {}

# -------------------------------------------------------------------
# 1) Function: Extract features for a single post
#    Mimics your training pipeline (same columns, same order).
# -------------------------------------------------------------------
def extract_single_post_features(post_json):
    """
    Given a single post (dict) with keys like 'caption', 'comments_count', etc.,
    return a 1D numpy array of features in the same order as the training code.
    """
    caption = post_json.get("caption", "") or ""

    # Basic text features
    caption_length = len(caption)
    hashtag_count  = caption.count("#")
    mention_count  = caption.count("@")

    # Additional text features
    words = caption.strip().split()
    word_count = len(words)
    avg_word_len = 0.0
    if word_count > 0:
        avg_word_len = sum(len(w) for w in words) / word_count
    emoji_count       = len(re.findall(r'[^\w\s,.;?!@#]', caption))
    exclamation_count = caption.count('!')
    question_count    = caption.count('?')
    link_presence     = 1 if ('http' in caption or 'www' in caption) else 0

    comments_count = post_json.get("comments_count", 0) or 0
    media_type     = 1 if post_json.get("media_type") == "IMAGE" else 0

    # Time-based features
    timestamp = post_json.get("timestamp")
    hour    = 0
    weekday = 0
    weekend = 0
    if timestamp:
        dt = datetime.fromisoformat(timestamp)
        hour = dt.hour
        weekday = dt.weekday()
        weekend = 1 if dt.weekday() >= 5 else 0

    # Return in the same order you used in training
    feature_vector = np.array([
        caption_length,
        hashtag_count,
        mention_count,
        comments_count,
        media_type,
        hour,
        weekday,
        weekend,
        word_count,
        avg_word_len,
        emoji_count,
        exclamation_count,
        question_count,
        link_presence
    ], dtype=float)  # float to ensure consistent shape for scaling

    return feature_vector

# -------------------------------------------------------------------
# 2) Read the new test .jsonl file line by line, build feature matrix
#    Then scale and predict with xgb_model
# -------------------------------------------------------------------
all_ids       = []
all_features  = []

with open(test_file_path, "r", encoding="utf-8") as fh:
    for line in fh:
        line = line.strip()
        if not line:
            continue  # skip empty lines
        post_json = json.loads(line)

        post_id = post_json.get("id")
        if not post_id:
            # If there's no 'id', skip or handle differently
            continue

        # Extract feature vector for this post
        feat_vec = extract_single_post_features(post_json)

        # Keep track of post_id and features
        all_ids.append(post_id)
        all_features.append(feat_vec)

# Convert to numpy array for batch scaling/prediction
all_features = np.array(all_features)

# -------------------------------------------------------------------
# 3) Scale the hour & weekday columns (indices [5, 6]) using
#    the *same scaler* you trained previously.
#    NOTE: We assume 'scaler' is already in memory.
# -------------------------------------------------------------------
all_features[:, 5:7] = scaler.transform(all_features[:, 5:7])

# -------------------------------------------------------------------
# 4) Predict using your trained XGB model
#    (We assume 'xgb_model' is loaded & in memory)
# -------------------------------------------------------------------
pred_log = xgb_model.predict(all_features)  # log-space predictions
pred_likes = np.expm1(pred_log)            # revert from log space

# Round to int
pred_likes = np.round(pred_likes).astype(int)

# -------------------------------------------------------------------
# 5) Build predictions_dict and save to JSON
# -------------------------------------------------------------------
for pid, plike in zip(all_ids, pred_likes):
    predictions_dict[pid] = int(plike)  # ensure it's an int, not np.int

with open(output_file_path, "w", encoding="utf-8") as outf:
    json.dump(predictions_dict, outf, indent=4)

print(f"Saved predictions to {output_file_path}. Sample:")
# Print a small slice of the dictionary
sample_keys = list(predictions_dict.keys())[:5]
for k in sample_keys:
    print(f"{k}: {predictions_dict[k]}")
# Out:
# Saved predictions to prediction-regression-round2.json. Sample:
# 17903451397703117: 132
# 17896404506845900: 338
# 17853971531941549: 476
# 18362044393058713: 429
# 17999365834969022: 759
