# %%
# !pip install xgboost==1.7.6
# Out:
# Collecting xgboost==1.7.6
#   Downloading xgboost-1.7.6-py3-none-manylinux2014_x86_64.whl.metadata (1.9 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from xgboost==1.7.6) (1.26.4)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from xgboost==1.7.6) (1.13.1)
# Downloading xgboost-1.7.6-py3-none-manylinux2014_x86_64.whl (200.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 200.3/200.3 MB 5.7 MB/s eta 0:00:00
# Installing collected packages: xgboost
#   Attempting uninstall: xgboost
#     Found existing installation: xgboost 2.1.3
#     Uninstalling xgboost-2.1.3:
#       Successfully uninstalled xgboost-2.1.3
# Successfully installed xgboost-1.7.6

# %%
import gzip
import json
import random

# Path to the gzipped dataset
data_path = "training-dataset.jsonl.gz"

# Initialize dictionaries for train and test data
train_data = {"profiles": {}, "posts": {}}
test_data = {"profiles": {}, "posts": {}}

# Load and shuffle the data
data_entries = []

with gzip.open(data_path, "rt") as fh:
    for line in fh:
        sample = json.loads(line)
        data_entries.append(sample)

# Shuffle the data to ensure randomness
random.shuffle(data_entries)

# Define the train-test split ratio
train_ratio = 0.8
train_size = int(len(data_entries) * train_ratio)

# Divide the data into train and test sets
train_post_count = 0
test_post_count = 0

for i, sample in enumerate(data_entries):
    profile = sample["profile"]
    username = profile["username"]
    posts = sample["posts"]

    if i < train_size:
        train_data["profiles"][username] = profile
        train_data["posts"][username] = posts
        train_post_count += len(posts)
    else:
        test_data["profiles"][username] = profile
        test_data["posts"][username] = posts
        test_post_count += len(posts)

# Output the sizes of train and test sets
print(f"Number of users in train data: {len(train_data['profiles'])}")
print(f"Number of posts in train data: {train_post_count}")
print(f"Number of users in test data: {len(test_data['profiles'])}")
print(f"Number of posts in test data: {test_post_count}")
# Out:
# Number of users in train data: 4332
# Number of posts in train data: 149873
# Number of users in test data: 1083
# Number of posts in test data: 37429

# %%
# Function to extract all unique columns (keys) from the posts
def extract_columns_from_data(data):
    columns = set()  # Use a set to store unique column names
    for posts in data["posts"].values():
        for post in posts:
            columns.update(post.keys())  # Add all keys from the current post
    return sorted(columns)  # Return sorted list of unique columns

# Extract columns for train_data and test_data
train_columns = extract_columns_from_data(train_data)
test_columns = extract_columns_from_data(test_data)

# Print the columns
print("Columns in train_data posts:")
print(train_columns)

print("\nColumns in test_data posts:")
print(test_columns)
# Out:
# Columns in train_data posts:
# ['caption', 'comments_count', 'id', 'like_count', 'media_type', 'media_url', 'timestamp']
#
# Columns in test_data posts:
# ['caption', 'comments_count', 'id', 'like_count', 'media_type', 'media_url', 'timestamp']

# %%
import numpy as np
import re
from datetime import datetime
from sklearn.preprocessing import MinMaxScaler

def extract_features_and_targets(data):
    features = []
    targets = []

    for username, posts in data["posts"].items():
        for post in posts:
            caption = post.get("caption", "") or ""

            # Basic text features
            caption_length = len(caption)
            hashtag_count  = caption.count("#")
            mention_count  = caption.count("@")

            # Additional text features
            # -------------------------------------------------------------
            # 1) word_count
            words = caption.strip().split()
            word_count = len(words)
            # 2) average_word_length
            avg_word_len = 0.0
            if word_count > 0:
                avg_word_len = sum(len(w) for w in words) / word_count
            # 3) emoji_count (naive approach: count non-alphanumeric symbols)
            #    or you can be more precise with an emoji regex
            emoji_count = len(re.findall(r'[^\w\s,.;?!@#]', caption))
            # 4) exclamation/question marks
            exclamation_count = caption.count('!')
            question_count    = caption.count('?')
            # 5) link presence
            link_presence = 1 if ('http' in caption or 'www' in caption) else 0
            # -------------------------------------------------------------

            comments_count = post.get("comments_count", 0) or 0
            media_type = 1 if post.get("media_type") == "IMAGE" else 0

            # Time-based features
            timestamp = post.get("timestamp")
            hour = 0
            weekday = 0
            weekend = 0
            if timestamp:
                dt = datetime.fromisoformat(timestamp)
                hour = dt.hour
                weekday = dt.weekday()
                weekend = 1 if dt.weekday() >= 5 else 0

            like_count = post.get("like_count", None)
            if like_count is not None:
                feature = [
                    caption_length,
                    hashtag_count,
                    mention_count,
                    comments_count,
                    media_type,
                    hour,
                    weekday,
                    weekend,
                    # New text features:
                    word_count,
                    avg_word_len,
                    emoji_count,
                    exclamation_count,
                    question_count,
                    link_presence
                ]
                features.append(feature)
                targets.append(int(like_count))  # Ensure target is integer

    return np.array(features), np.array(targets)

# ------------------------------------------------------
# Extract features/targets for train & test
train_features, train_targets = extract_features_and_targets(train_data)
test_features, test_targets   = extract_features_and_targets(test_data)

# Remove outliers in target based on IQR
q1 = np.percentile(train_targets, 25)
q3 = np.percentile(train_targets, 75)
iqr = q3 - q1
lower_bound = q1 - 1.5 * iqr
upper_bound = q3 + 1.5 * iqr
filtered_indices = (train_targets >= lower_bound) & (train_targets <= upper_bound)
train_features = train_features[filtered_indices]
train_targets  = train_targets[filtered_indices]

# We only scale time-based features (hour, weekday), but now they are at indices 5,6
# (Also be mindful if you want to scale other numeric features).
scaler = MinMaxScaler()
train_features[:, 5:7] = scaler.fit_transform(train_features[:, 5:7])
test_features[:, 5:7]  = scaler.transform(test_features[:, 5:7])

# %%
# If not installed:
# %pip install xgboost

import numpy as np
import xgboost as xgb
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score

# 1) Train/validation/test Split
X_train, X_val, y_train, y_val = train_test_split(
    train_features,
    train_targets,
    test_size=0.2,
    random_state=42
)

# 2) Transform the target via log1p
y_train_log = np.log1p(y_train)
y_val_log   = np.log1p(y_val)
y_test_log  = np.log1p(test_targets)

# 3) Create XGB model
# Feel free to adjust hyperparameters
xgb_model = xgb.XGBRegressor(
    n_estimators=1000,
    learning_rate=0.05,
    max_depth=6,
    subsample=0.8,
    colsample_bytree=0.8,
    random_state=42
)

# 4) Train with early stopping on validation set
xgb_model.fit(
    X_train,
    y_train_log,
    eval_set=[(X_val, y_val_log)],
    early_stopping_rounds=25,
    verbose=True
)

# 5) Evaluate on Validation
val_pred_log = xgb_model.predict(X_val)
val_pred     = np.round(np.expm1(val_pred_log)).astype(int)

val_log_mse = np.mean((np.log1p(y_val) - np.log1p(val_pred))**2)
val_r2      = r2_score(y_val, val_pred)
print("XGBoost Validation Log MSE:", val_log_mse)
print("XGBoost Validation R²:", val_r2)

# 6) Evaluate on Test
test_pred_log = xgb_model.predict(test_features)
test_pred     = np.round(np.expm1(test_pred_log)).astype(int)

test_log_mse = np.mean((y_test_log - np.log1p(test_pred))**2)
test_r2      = r2_score(test_targets, test_pred)
print("XGBoost Test Log MSE:", test_log_mse)
print("XGBoost Test R²:", test_r2)

# 7) Some sample predictions
print("\nSample Predictions (XGB):")
for true, pred in zip(test_targets[:10], test_pred[:10]):
    print(f"Actual: {true}, Predicted: {pred}")
# Out:
# [0]	validation_0-rmse:3.49611
# /usr/local/lib/python3.10/dist-packages/xgboost/sklearn.py:835: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [1]	validation_0-rmse:3.33683
# [2]	validation_0-rmse:3.18632
# [3]	validation_0-rmse:3.04389
# [4]	validation_0-rmse:2.90928
# [5]	validation_0-rmse:2.78778
# [6]	validation_0-rmse:2.66773
# [7]	validation_0-rmse:2.55448
# [8]	validation_0-rmse:2.44767
# [9]	validation_0-rmse:2.34737
# [10]	validation_0-rmse:2.25735
# [11]	validation_0-rmse:2.17273
# [12]	validation_0-rmse:2.08879
# [13]	validation_0-rmse:2.00995
# [14]	validation_0-rmse:1.93585
# [15]	validation_0-rmse:1.86664
# [16]	validation_0-rmse:1.80173
# [17]	validation_0-rmse:1.74436
# [18]	validation_0-rmse:1.69072
# [19]	validation_0-rmse:1.63737
# [20]	validation_0-rmse:1.59104
# [21]	validation_0-rmse:1.54458
# [22]	validation_0-rmse:1.50115
# [23]	validation_0-rmse:1.46098
# [24]	validation_0-rmse:1.42364
# [25]	validation_0-rmse:1.38915
# [26]	validation_0-rmse:1.35732
# [27]	validation_0-rmse:1.32796
# [28]	validation_0-rmse:1.30084
# [29]	validation_0-rmse:1.27763
# [30]	validation_0-rmse:1.25448
# [31]	validation_0-rmse:1.23307
# [32]	validation_0-rmse:1.21349
# [33]	validation_0-rmse:1.19550
# [34]	validation_0-rmse:1.17897
# [35]	validation_0-rmse:1.16381
# [36]	validation_0-rmse:1.14994
# [37]	validation_0-rmse:1.13716
# [38]	validation_0-rmse:1.12561
# [39]	validation_0-rmse:1.11513
# [40]	validation_0-rmse:1.10571
# [41]	validation_0-rmse:1.09698
# [42]	validation_0-rmse:1.08906
# [43]	validation_0-rmse:1.08224
# [44]	validation_0-rmse:1.07557
# [45]	validation_0-rmse:1.06986
# [46]	validation_0-rmse:1.06433
# [47]	validation_0-rmse:1.05943
# [48]	validation_0-rmse:1.05502
# [49]	validation_0-rmse:1.05078
# [50]	validation_0-rmse:1.04727
# [51]	validation_0-rmse:1.04373
# [52]	validation_0-rmse:1.04048
# [53]	validation_0-rmse:1.03758
# [54]	validation_0-rmse:1.03500
# [55]	validation_0-rmse:1.03258
# [56]	validation_0-rmse:1.03040
# [57]	validation_0-rmse:1.02840
# [58]	validation_0-rmse:1.02662
# [59]	validation_0-rmse:1.02499
# [60]	validation_0-rmse:1.02341
# [61]	validation_0-rmse:1.02197
# [62]	validation_0-rmse:1.02064
# [63]	validation_0-rmse:1.01943
# [64]	validation_0-rmse:1.01840
# [65]	validation_0-rmse:1.01742
# [66]	validation_0-rmse:1.01649
# [67]	validation_0-rmse:1.01561
# [68]	validation_0-rmse:1.01483
# [69]	validation_0-rmse:1.01411
# [70]	validation_0-rmse:1.01344
# [71]	validation_0-rmse:1.01281
# [72]	validation_0-rmse:1.01227
# [73]	validation_0-rmse:1.01179
# [74]	validation_0-rmse:1.01132
# [75]	validation_0-rmse:1.01087
# [76]	validation_0-rmse:1.01046
# [77]	validation_0-rmse:1.01011
# [78]	validation_0-rmse:1.00983
# [79]	validation_0-rmse:1.00953
# [80]	validation_0-rmse:1.00927
# [81]	validation_0-rmse:1.00894
# [82]	validation_0-rmse:1.00857
# [83]	validation_0-rmse:1.00817
# [84]	validation_0-rmse:1.00785
# [85]	validation_0-rmse:1.00766
# [86]	validation_0-rmse:1.00748
# [87]	validation_0-rmse:1.00718
# [88]	validation_0-rmse:1.00695
# [89]	validation_0-rmse:1.00674
# [90]	validation_0-rmse:1.00652
# [91]	validation_0-rmse:1.00630
# [92]	validation_0-rmse:1.00613
# [93]	validation_0-rmse:1.00586
# [94]	validation_0-rmse:1.00571
# [95]	validation_0-rmse:1.00555
# [96]	validation_0-rmse:1.00531
# [97]	validation_0-rmse:1.00520
# [98]	validation_0-rmse:1.00510
# [99]	validation_0-rmse:1.00491
# [100]	validation_0-rmse:1.00479
# [101]	validation_0-rmse:1.00469
# [102]	validation_0-rmse:1.00460
# [103]	validation_0-rmse:1.00447
# [104]	validation_0-rmse:1.00433
# [105]	validation_0-rmse:1.00423
# [106]	validation_0-rmse:1.00410
# [107]	validation_0-rmse:1.00397
# [108]	validation_0-rmse:1.00386
# [109]	validation_0-rmse:1.00382
# [110]	validation_0-rmse:1.00370
# [111]	validation_0-rmse:1.00354
# [112]	validation_0-rmse:1.00346
# [113]	validation_0-rmse:1.00317
# [114]	validation_0-rmse:1.00299
# [115]	validation_0-rmse:1.00291
# [116]	validation_0-rmse:1.00284
# [117]	validation_0-rmse:1.00271
# [118]	validation_0-rmse:1.00267
# [119]	validation_0-rmse:1.00257
# [120]	validation_0-rmse:1.00245
# [121]	validation_0-rmse:1.00239
# [122]	validation_0-rmse:1.00230
# [123]	validation_0-rmse:1.00218
# [124]	validation_0-rmse:1.00208
# [125]	validation_0-rmse:1.00194
# [126]	validation_0-rmse:1.00183
# [127]	validation_0-rmse:1.00177
# [128]	validation_0-rmse:1.00163
# [129]	validation_0-rmse:1.00156
# [130]	validation_0-rmse:1.00153
# [131]	validation_0-rmse:1.00149
# [132]	validation_0-rmse:1.00141
# [133]	validation_0-rmse:1.00128
# [134]	validation_0-rmse:1.00119
# [135]	validation_0-rmse:1.00107
# [136]	validation_0-rmse:1.00093
# [137]	validation_0-rmse:1.00085
# [138]	validation_0-rmse:1.00071
# [139]	validation_0-rmse:1.00063
# [140]	validation_0-rmse:1.00060
# [141]	validation_0-rmse:1.00051
# [142]	validation_0-rmse:1.00042
# [143]	validation_0-rmse:1.00025
# [144]	validation_0-rmse:1.00016
# [145]	validation_0-rmse:1.00002
# [146]	validation_0-rmse:0.99999
# [147]	validation_0-rmse:0.99996
# [148]	validation_0-rmse:0.99992
# [149]	validation_0-rmse:0.99972
# [150]	validation_0-rmse:0.99969
# [151]	validation_0-rmse:0.99957
# [152]	validation_0-rmse:0.99943
# [153]	validation_0-rmse:0.99921
# [154]	validation_0-rmse:0.99913
# [155]	validation_0-rmse:0.99910
# [156]	validation_0-rmse:0.99892
# [157]	validation_0-rmse:0.99884
# [158]	validation_0-rmse:0.99874
# [159]	validation_0-rmse:0.99869
# [160]	validation_0-rmse:0.99864
# [161]	validation_0-rmse:0.99848
# [162]	validation_0-rmse:0.99841
# [163]	validation_0-rmse:0.99826
# [164]	validation_0-rmse:0.99816
# [165]	validation_0-rmse:0.99807
# [166]	validation_0-rmse:0.99800
# [167]	validation_0-rmse:0.99797
# [168]	validation_0-rmse:0.99780
# [169]	validation_0-rmse:0.99775
# [170]	validation_0-rmse:0.99769
# [171]	validation_0-rmse:0.99757
# [172]	validation_0-rmse:0.99750
# [173]	validation_0-rmse:0.99743
# [174]	validation_0-rmse:0.99735
# [175]	validation_0-rmse:0.99734
# [176]	validation_0-rmse:0.99734
# [177]	validation_0-rmse:0.99725
# [178]	validation_0-rmse:0.99722
# [179]	validation_0-rmse:0.99720
# [180]	validation_0-rmse:0.99715
# [181]	validation_0-rmse:0.99710
# [182]	validation_0-rmse:0.99709
# [183]	validation_0-rmse:0.99702
# [184]	validation_0-rmse:0.99699
# [185]	validation_0-rmse:0.99693
# [186]	validation_0-rmse:0.99689
# [187]	validation_0-rmse:0.99685
# [188]	validation_0-rmse:0.99679
# [189]	validation_0-rmse:0.99676
# [190]	validation_0-rmse:0.99668
# [191]	validation_0-rmse:0.99664
# [192]	validation_0-rmse:0.99663
# [193]	validation_0-rmse:0.99653
# [194]	validation_0-rmse:0.99650
# [195]	validation_0-rmse:0.99647
# [196]	validation_0-rmse:0.99647
# [197]	validation_0-rmse:0.99646
# [198]	validation_0-rmse:0.99641
# [199]	validation_0-rmse:0.99633
# [200]	validation_0-rmse:0.99629
# [201]	validation_0-rmse:0.99627
# [202]	validation_0-rmse:0.99618
# [203]	validation_0-rmse:0.99608
# [204]	validation_0-rmse:0.99601
# [205]	validation_0-rmse:0.99601
# [206]	validation_0-rmse:0.99589
# [207]	validation_0-rmse:0.99581
# [208]	validation_0-rmse:0.99579
# [209]	validation_0-rmse:0.99573
# [210]	validation_0-rmse:0.99569
# [211]	validation_0-rmse:0.99567
# [212]	validation_0-rmse:0.99566
# [213]	validation_0-rmse:0.99562
# [214]	validation_0-rmse:0.99554
# [215]	validation_0-rmse:0.99544
# [216]	validation_0-rmse:0.99540
# [217]	validation_0-rmse:0.99540
# [218]	validation_0-rmse:0.99535
# [219]	validation_0-rmse:0.99531
# [220]	validation_0-rmse:0.99530
# [221]	validation_0-rmse:0.99524
# [222]	validation_0-rmse:0.99524
# [223]	validation_0-rmse:0.99522
# [224]	validation_0-rmse:0.99517
# [225]	validation_0-rmse:0.99512
# [226]	validation_0-rmse:0.99501
# [227]	validation_0-rmse:0.99499
# [228]	validation_0-rmse:0.99490
# [229]	validation_0-rmse:0.99474
# [230]	validation_0-rmse:0.99469
# [231]	validation_0-rmse:0.99461
# [232]	validation_0-rmse:0.99454
# [233]	validation_0-rmse:0.99447
# [234]	validation_0-rmse:0.99445
# [235]	validation_0-rmse:0.99444
# [236]	validation_0-rmse:0.99429
# [237]	validation_0-rmse:0.99425
# [238]	validation_0-rmse:0.99419
# [239]	validation_0-rmse:0.99415
# [240]	validation_0-rmse:0.99412
# [241]	validation_0-rmse:0.99415
# [242]	validation_0-rmse:0.99411
# [243]	validation_0-rmse:0.99410
# [244]	validation_0-rmse:0.99407
# [245]	validation_0-rmse:0.99399
# [246]	validation_0-rmse:0.99395
# [247]	validation_0-rmse:0.99395
# [248]	validation_0-rmse:0.99391
# [249]	validation_0-rmse:0.99377
# [250]	validation_0-rmse:0.99374
# [251]	validation_0-rmse:0.99370
# [252]	validation_0-rmse:0.99370
# [253]	validation_0-rmse:0.99367
# [254]	validation_0-rmse:0.99363
# [255]	validation_0-rmse:0.99354
# [256]	validation_0-rmse:0.99353
# [257]	validation_0-rmse:0.99350
# [258]	validation_0-rmse:0.99344
# [259]	validation_0-rmse:0.99339
# [260]	validation_0-rmse:0.99339
# [261]	validation_0-rmse:0.99337
# [262]	validation_0-rmse:0.99329
# [263]	validation_0-rmse:0.99327
# [264]	validation_0-rmse:0.99328
# [265]	validation_0-rmse:0.99325
# [266]	validation_0-rmse:0.99315
# [267]	validation_0-rmse:0.99312
# [268]	validation_0-rmse:0.99311
# [269]	validation_0-rmse:0.99302
# [270]	validation_0-rmse:0.99301
# [271]	validation_0-rmse:0.99299
# [272]	validation_0-rmse:0.99296
# [273]	validation_0-rmse:0.99294
# [274]	validation_0-rmse:0.99292
# [275]	validation_0-rmse:0.99290
# [276]	validation_0-rmse:0.99277
# [277]	validation_0-rmse:0.99275
# [278]	validation_0-rmse:0.99273
# [279]	validation_0-rmse:0.99273
# [280]	validation_0-rmse:0.99273
# [281]	validation_0-rmse:0.99272
# [282]	validation_0-rmse:0.99268
# [283]	validation_0-rmse:0.99268
# [284]	validation_0-rmse:0.99260
# [285]	validation_0-rmse:0.99258
# [286]	validation_0-rmse:0.99258
# [287]	validation_0-rmse:0.99251
# [288]	validation_0-rmse:0.99251
# [289]	validation_0-rmse:0.99251
# [290]	validation_0-rmse:0.99248
# [291]	validation_0-rmse:0.99241
# [292]	validation_0-rmse:0.99237
# [293]	validation_0-rmse:0.99238
# [294]	validation_0-rmse:0.99238
# [295]	validation_0-rmse:0.99230
# [296]	validation_0-rmse:0.99229
# [297]	validation_0-rmse:0.99226
# [298]	validation_0-rmse:0.99227
# [299]	validation_0-rmse:0.99225
# [300]	validation_0-rmse:0.99223
# [301]	validation_0-rmse:0.99218
# [302]	validation_0-rmse:0.99214
# [303]	validation_0-rmse:0.99207
# [304]	validation_0-rmse:0.99205
# [305]	validation_0-rmse:0.99201
# [306]	validation_0-rmse:0.99191
# [307]	validation_0-rmse:0.99190
# [308]	validation_0-rmse:0.99191
# [309]	validation_0-rmse:0.99188
# [310]	validation_0-rmse:0.99187
# [311]	validation_0-rmse:0.99187
# [312]	validation_0-rmse:0.99180
# [313]	validation_0-rmse:0.99177
# [314]	validation_0-rmse:0.99174
# [315]	validation_0-rmse:0.99168
# [316]	validation_0-rmse:0.99157
# [317]	validation_0-rmse:0.99146
# [318]	validation_0-rmse:0.99140
# [319]	validation_0-rmse:0.99140
# [320]	validation_0-rmse:0.99134
# [321]	validation_0-rmse:0.99134
# [322]	validation_0-rmse:0.99131
# [323]	validation_0-rmse:0.99123
# [324]	validation_0-rmse:0.99113
# [325]	validation_0-rmse:0.99112
# [326]	validation_0-rmse:0.99111
# [327]	validation_0-rmse:0.99108
# [328]	validation_0-rmse:0.99104
# [329]	validation_0-rmse:0.99102
# [330]	validation_0-rmse:0.99100
# [331]	validation_0-rmse:0.99094
# [332]	validation_0-rmse:0.99093
# [333]	validation_0-rmse:0.99089
# [334]	validation_0-rmse:0.99081
# [335]	validation_0-rmse:0.99075
# [336]	validation_0-rmse:0.99064
# [337]	validation_0-rmse:0.99062
# [338]	validation_0-rmse:0.99061
# [339]	validation_0-rmse:0.99059
# [340]	validation_0-rmse:0.99057
# [341]	validation_0-rmse:0.99052
# [342]	validation_0-rmse:0.99048
# [343]	validation_0-rmse:0.99045
# [344]	validation_0-rmse:0.99041
# [345]	validation_0-rmse:0.99036
# [346]	validation_0-rmse:0.99032
# [347]	validation_0-rmse:0.99026
# [348]	validation_0-rmse:0.99026
# [349]	validation_0-rmse:0.99025
# [350]	validation_0-rmse:0.99022
# [351]	validation_0-rmse:0.99021
# [352]	validation_0-rmse:0.99019
# [353]	validation_0-rmse:0.99013
# [354]	validation_0-rmse:0.99009
# [355]	validation_0-rmse:0.99001
# [356]	validation_0-rmse:0.98993
# [357]	validation_0-rmse:0.98991
# [358]	validation_0-rmse:0.98987
# [359]	validation_0-rmse:0.98987
# [360]	validation_0-rmse:0.98985
# [361]	validation_0-rmse:0.98984
# [362]	validation_0-rmse:0.98983
# [363]	validation_0-rmse:0.98980
# [364]	validation_0-rmse:0.98980
# [365]	validation_0-rmse:0.98976
# [366]	validation_0-rmse:0.98977
# [367]	validation_0-rmse:0.98977
# [368]	validation_0-rmse:0.98973
# [369]	validation_0-rmse:0.98972
# [370]	validation_0-rmse:0.98969
# [371]	validation_0-rmse:0.98968
# [372]	validation_0-rmse:0.98961
# [373]	validation_0-rmse:0.98961
# [374]	validation_0-rmse:0.98959
# [375]	validation_0-rmse:0.98958
# [376]	validation_0-rmse:0.98956
# [377]	validation_0-rmse:0.98954
# [378]	validation_0-rmse:0.98951
# [379]	validation_0-rmse:0.98951
# [380]	validation_0-rmse:0.98949
# [381]	validation_0-rmse:0.98943
# [382]	validation_0-rmse:0.98945
# [383]	validation_0-rmse:0.98943
# [384]	validation_0-rmse:0.98939
# [385]	validation_0-rmse:0.98936
# [386]	validation_0-rmse:0.98934
# [387]	validation_0-rmse:0.98935
# [388]	validation_0-rmse:0.98933
# [389]	validation_0-rmse:0.98930
# [390]	validation_0-rmse:0.98928
# [391]	validation_0-rmse:0.98918
# [392]	validation_0-rmse:0.98916
# [393]	validation_0-rmse:0.98917
# [394]	validation_0-rmse:0.98914
# [395]	validation_0-rmse:0.98913
# [396]	validation_0-rmse:0.98913
# [397]	validation_0-rmse:0.98910
# [398]	validation_0-rmse:0.98909
# [399]	validation_0-rmse:0.98909
# [400]	validation_0-rmse:0.98912
# [401]	validation_0-rmse:0.98909
# [402]	validation_0-rmse:0.98907
# [403]	validation_0-rmse:0.98906
# [404]	validation_0-rmse:0.98901
# [405]	validation_0-rmse:0.98895
# [406]	validation_0-rmse:0.98893
# [407]	validation_0-rmse:0.98888
# [408]	validation_0-rmse:0.98888
# [409]	validation_0-rmse:0.98889
# [410]	validation_0-rmse:0.98886
# [411]	validation_0-rmse:0.98882
# [412]	validation_0-rmse:0.98882
# [413]	validation_0-rmse:0.98883
# [414]	validation_0-rmse:0.98884
# [415]	validation_0-rmse:0.98882
# [416]	validation_0-rmse:0.98881
# [417]	validation_0-rmse:0.98883
# [418]	validation_0-rmse:0.98876
# [419]	validation_0-rmse:0.98870
# [420]	validation_0-rmse:0.98862
# [421]	validation_0-rmse:0.98860
# [422]	validation_0-rmse:0.98857
# [423]	validation_0-rmse:0.98857
# [424]	validation_0-rmse:0.98854
# [425]	validation_0-rmse:0.98853
# [426]	validation_0-rmse:0.98850
# [427]	validation_0-rmse:0.98851
# [428]	validation_0-rmse:0.98848
# [429]	validation_0-rmse:0.98848
# [430]	validation_0-rmse:0.98845
# [431]	validation_0-rmse:0.98845
# [432]	validation_0-rmse:0.98844
# [433]	validation_0-rmse:0.98835
# [434]	validation_0-rmse:0.98830
# [435]	validation_0-rmse:0.98826
# [436]	validation_0-rmse:0.98822
# [437]	validation_0-rmse:0.98820
# [438]	validation_0-rmse:0.98820
# [439]	validation_0-rmse:0.98818
# [440]	validation_0-rmse:0.98815
# [441]	validation_0-rmse:0.98815
# [442]	validation_0-rmse:0.98812
# [443]	validation_0-rmse:0.98810
# [444]	validation_0-rmse:0.98806
# [445]	validation_0-rmse:0.98803
# [446]	validation_0-rmse:0.98803
# [447]	validation_0-rmse:0.98799
# [448]	validation_0-rmse:0.98798
# [449]	validation_0-rmse:0.98793
# [450]	validation_0-rmse:0.98794
# [451]	validation_0-rmse:0.98790
# [452]	validation_0-rmse:0.98790
# [453]	validation_0-rmse:0.98791
# [454]	validation_0-rmse:0.98788
# [455]	validation_0-rmse:0.98788
# [456]	validation_0-rmse:0.98786
# [457]	validation_0-rmse:0.98783
# [458]	validation_0-rmse:0.98783
# [459]	validation_0-rmse:0.98781
# [460]	validation_0-rmse:0.98780
# [461]	validation_0-rmse:0.98775
# [462]	validation_0-rmse:0.98773
# [463]	validation_0-rmse:0.98772
# [464]	validation_0-rmse:0.98774
# [465]	validation_0-rmse:0.98772
# [466]	validation_0-rmse:0.98772
# [467]	validation_0-rmse:0.98769
# [468]	validation_0-rmse:0.98767
# [469]	validation_0-rmse:0.98768
# [470]	validation_0-rmse:0.98766
# [471]	validation_0-rmse:0.98764
# [472]	validation_0-rmse:0.98759
# [473]	validation_0-rmse:0.98758
# [474]	validation_0-rmse:0.98751
# [475]	validation_0-rmse:0.98748
# [476]	validation_0-rmse:0.98750
# [477]	validation_0-rmse:0.98752
# [478]	validation_0-rmse:0.98748
# [479]	validation_0-rmse:0.98742
# [480]	validation_0-rmse:0.98741
# [481]	validation_0-rmse:0.98740
# [482]	validation_0-rmse:0.98738
# [483]	validation_0-rmse:0.98739
# [484]	validation_0-rmse:0.98738
# [485]	validation_0-rmse:0.98738
# [486]	validation_0-rmse:0.98737
# [487]	validation_0-rmse:0.98737
# [488]	validation_0-rmse:0.98735
# [489]	validation_0-rmse:0.98731
# [490]	validation_0-rmse:0.98721
# [491]	validation_0-rmse:0.98720
# [492]	validation_0-rmse:0.98720
# [493]	validation_0-rmse:0.98724
# [494]	validation_0-rmse:0.98721
# [495]	validation_0-rmse:0.98719
# [496]	validation_0-rmse:0.98715
# [497]	validation_0-rmse:0.98713
# [498]	validation_0-rmse:0.98707
# [499]	validation_0-rmse:0.98707
# [500]	validation_0-rmse:0.98705
# [501]	validation_0-rmse:0.98699
# [502]	validation_0-rmse:0.98696
# [503]	validation_0-rmse:0.98696
# [504]	validation_0-rmse:0.98697
# [505]	validation_0-rmse:0.98698
# [506]	validation_0-rmse:0.98690
# [507]	validation_0-rmse:0.98687
# [508]	validation_0-rmse:0.98686
# [509]	validation_0-rmse:0.98685
# [510]	validation_0-rmse:0.98685
# [511]	validation_0-rmse:0.98683
# [512]	validation_0-rmse:0.98683
# [513]	validation_0-rmse:0.98684
# [514]	validation_0-rmse:0.98683
# [515]	validation_0-rmse:0.98682
# [516]	validation_0-rmse:0.98678
# [517]	validation_0-rmse:0.98680
# [518]	validation_0-rmse:0.98678
# [519]	validation_0-rmse:0.98674
# [520]	validation_0-rmse:0.98674
# [521]	validation_0-rmse:0.98670
# [522]	validation_0-rmse:0.98668
# [523]	validation_0-rmse:0.98665
# [524]	validation_0-rmse:0.98663
# [525]	validation_0-rmse:0.98661
# [526]	validation_0-rmse:0.98658
# [527]	validation_0-rmse:0.98659
# [528]	validation_0-rmse:0.98660
# [529]	validation_0-rmse:0.98657
# [530]	validation_0-rmse:0.98652
# [531]	validation_0-rmse:0.98651
# [532]	validation_0-rmse:0.98647
# [533]	validation_0-rmse:0.98646
# [534]	validation_0-rmse:0.98643
# [535]	validation_0-rmse:0.98643
# [536]	validation_0-rmse:0.98644
# [537]	validation_0-rmse:0.98640
# [538]	validation_0-rmse:0.98642
# [539]	validation_0-rmse:0.98638
# [540]	validation_0-rmse:0.98639
# [541]	validation_0-rmse:0.98637
# [542]	validation_0-rmse:0.98636
# [543]	validation_0-rmse:0.98638
# [544]	validation_0-rmse:0.98635
# [545]	validation_0-rmse:0.98635
# [546]	validation_0-rmse:0.98634
# [547]	validation_0-rmse:0.98635
# [548]	validation_0-rmse:0.98634
# [549]	validation_0-rmse:0.98632
# [550]	validation_0-rmse:0.98632
# [551]	validation_0-rmse:0.98629
# [552]	validation_0-rmse:0.98631
# [553]	validation_0-rmse:0.98631
# [554]	validation_0-rmse:0.98631
# [555]	validation_0-rmse:0.98633
# [556]	validation_0-rmse:0.98632
# [557]	validation_0-rmse:0.98629
# [558]	validation_0-rmse:0.98628
# [559]	validation_0-rmse:0.98626
# [560]	validation_0-rmse:0.98624
# [561]	validation_0-rmse:0.98628
# [562]	validation_0-rmse:0.98625
# [563]	validation_0-rmse:0.98624
# [564]	validation_0-rmse:0.98618
# [565]	validation_0-rmse:0.98618
# [566]	validation_0-rmse:0.98618
# [567]	validation_0-rmse:0.98620
# [568]	validation_0-rmse:0.98619
# [569]	validation_0-rmse:0.98618
# [570]	validation_0-rmse:0.98615
# [571]	validation_0-rmse:0.98611
# [572]	validation_0-rmse:0.98610
# [573]	validation_0-rmse:0.98610
# [574]	validation_0-rmse:0.98609
# [575]	validation_0-rmse:0.98602
# [576]	validation_0-rmse:0.98597
# [577]	validation_0-rmse:0.98598
# [578]	validation_0-rmse:0.98599
# [579]	validation_0-rmse:0.98599
# [580]	validation_0-rmse:0.98601
# [581]	validation_0-rmse:0.98597
# [582]	validation_0-rmse:0.98592
# [583]	validation_0-rmse:0.98591
# [584]	validation_0-rmse:0.98589
# [585]	validation_0-rmse:0.98589
# [586]	validation_0-rmse:0.98590
# [587]	validation_0-rmse:0.98590
# [588]	validation_0-rmse:0.98585
# [589]	validation_0-rmse:0.98583
# [590]	validation_0-rmse:0.98584
# [591]	validation_0-rmse:0.98582
# [592]	validation_0-rmse:0.98579
# [593]	validation_0-rmse:0.98578
# [594]	validation_0-rmse:0.98577
# [595]	validation_0-rmse:0.98576
# [596]	validation_0-rmse:0.98573
# [597]	validation_0-rmse:0.98576
# [598]	validation_0-rmse:0.98574
# [599]	validation_0-rmse:0.98574
# [600]	validation_0-rmse:0.98574
# [601]	validation_0-rmse:0.98567
# [602]	validation_0-rmse:0.98563
# [603]	validation_0-rmse:0.98560
# [604]	validation_0-rmse:0.98558
# [605]	validation_0-rmse:0.98559
# [606]	validation_0-rmse:0.98558
# [607]	validation_0-rmse:0.98560
# [608]	validation_0-rmse:0.98559
# [609]	validation_0-rmse:0.98555
# [610]	validation_0-rmse:0.98553
# [611]	validation_0-rmse:0.98552
# [612]	validation_0-rmse:0.98552
# [613]	validation_0-rmse:0.98552
# [614]	validation_0-rmse:0.98547
# [615]	validation_0-rmse:0.98547
# [616]	validation_0-rmse:0.98543
# [617]	validation_0-rmse:0.98541
# [618]	validation_0-rmse:0.98541
# [619]	validation_0-rmse:0.98539
# [620]	validation_0-rmse:0.98540
# [621]	validation_0-rmse:0.98539
# [622]	validation_0-rmse:0.98533
# [623]	validation_0-rmse:0.98533
# [624]	validation_0-rmse:0.98532
# [625]	validation_0-rmse:0.98532
# [626]	validation_0-rmse:0.98530
# [627]	validation_0-rmse:0.98530
# [628]	validation_0-rmse:0.98530
# [629]	validation_0-rmse:0.98527
# [630]	validation_0-rmse:0.98524
# [631]	validation_0-rmse:0.98519
# [632]	validation_0-rmse:0.98520
# [633]	validation_0-rmse:0.98519
# [634]	validation_0-rmse:0.98518
# [635]	validation_0-rmse:0.98519
# [636]	validation_0-rmse:0.98516
# [637]	validation_0-rmse:0.98517
# [638]	validation_0-rmse:0.98516
# [639]	validation_0-rmse:0.98514
# [640]	validation_0-rmse:0.98513
# [641]	validation_0-rmse:0.98514
# [642]	validation_0-rmse:0.98510
# [643]	validation_0-rmse:0.98510
# [644]	validation_0-rmse:0.98504
# [645]	validation_0-rmse:0.98506
# [646]	validation_0-rmse:0.98506
# [647]	validation_0-rmse:0.98505
# [648]	validation_0-rmse:0.98504
# [649]	validation_0-rmse:0.98502
# [650]	validation_0-rmse:0.98501
# [651]	validation_0-rmse:0.98500
# [652]	validation_0-rmse:0.98500
# [653]	validation_0-rmse:0.98502
# [654]	validation_0-rmse:0.98499
# [655]	validation_0-rmse:0.98497
# [656]	validation_0-rmse:0.98495
# [657]	validation_0-rmse:0.98494
# [658]	validation_0-rmse:0.98492
# [659]	validation_0-rmse:0.98494
# [660]	validation_0-rmse:0.98490
# [661]	validation_0-rmse:0.98490
# [662]	validation_0-rmse:0.98490
# [663]	validation_0-rmse:0.98489
# [664]	validation_0-rmse:0.98488
# [665]	validation_0-rmse:0.98490
# [666]	validation_0-rmse:0.98488
# [667]	validation_0-rmse:0.98488
# [668]	validation_0-rmse:0.98486
# [669]	validation_0-rmse:0.98484
# [670]	validation_0-rmse:0.98483
# [671]	validation_0-rmse:0.98481
# [672]	validation_0-rmse:0.98481
# [673]	validation_0-rmse:0.98475
# [674]	validation_0-rmse:0.98471
# [675]	validation_0-rmse:0.98463
# [676]	validation_0-rmse:0.98464
# [677]	validation_0-rmse:0.98463
# [678]	validation_0-rmse:0.98465
# [679]	validation_0-rmse:0.98462
# [680]	validation_0-rmse:0.98462
# [681]	validation_0-rmse:0.98460
# [682]	validation_0-rmse:0.98457
# [683]	validation_0-rmse:0.98458
# [684]	validation_0-rmse:0.98457
# [685]	validation_0-rmse:0.98458
# [686]	validation_0-rmse:0.98456
# [687]	validation_0-rmse:0.98458
# [688]	validation_0-rmse:0.98455
# [689]	validation_0-rmse:0.98454
# [690]	validation_0-rmse:0.98454
# [691]	validation_0-rmse:0.98454
# [692]	validation_0-rmse:0.98451
# [693]	validation_0-rmse:0.98451
# [694]	validation_0-rmse:0.98451
# [695]	validation_0-rmse:0.98449
# [696]	validation_0-rmse:0.98440
# [697]	validation_0-rmse:0.98438
# [698]	validation_0-rmse:0.98436
# [699]	validation_0-rmse:0.98435
# [700]	validation_0-rmse:0.98437
# [701]	validation_0-rmse:0.98436
# [702]	validation_0-rmse:0.98437
# [703]	validation_0-rmse:0.98435
# [704]	validation_0-rmse:0.98430
# [705]	validation_0-rmse:0.98431
# [706]	validation_0-rmse:0.98431
# [707]	validation_0-rmse:0.98429
# [708]	validation_0-rmse:0.98428
# [709]	validation_0-rmse:0.98429
# [710]	validation_0-rmse:0.98429
# [711]	validation_0-rmse:0.98430
# [712]	validation_0-rmse:0.98429
# [713]	validation_0-rmse:0.98430
# [714]	validation_0-rmse:0.98426
# [715]	validation_0-rmse:0.98426
# [716]	validation_0-rmse:0.98424
# [717]	validation_0-rmse:0.98426
# [718]	validation_0-rmse:0.98429
# [719]	validation_0-rmse:0.98430
# [720]	validation_0-rmse:0.98428
# [721]	validation_0-rmse:0.98429
# [722]	validation_0-rmse:0.98428
# [723]	validation_0-rmse:0.98431
# [724]	validation_0-rmse:0.98431
# [725]	validation_0-rmse:0.98433
# [726]	validation_0-rmse:0.98433
# [727]	validation_0-rmse:0.98431
# [728]	validation_0-rmse:0.98433
# [729]	validation_0-rmse:0.98432
# [730]	validation_0-rmse:0.98430
# [731]	validation_0-rmse:0.98430
# [732]	validation_0-rmse:0.98428
# [733]	validation_0-rmse:0.98427
# [734]	validation_0-rmse:0.98428
# [735]	validation_0-rmse:0.98426
# [736]	validation_0-rmse:0.98428
# [737]	validation_0-rmse:0.98430
# [738]	validation_0-rmse:0.98428
# [739]	validation_0-rmse:0.98427
# [740]	validation_0-rmse:0.98426
# [741]	validation_0-rmse:0.98421
# [742]	validation_0-rmse:0.98420
# [743]	validation_0-rmse:0.98417
# [744]	validation_0-rmse:0.98416
# [745]	validation_0-rmse:0.98418
# [746]	validation_0-rmse:0.98419
# [747]	validation_0-rmse:0.98417
# [748]	validation_0-rmse:0.98414
# [749]	validation_0-rmse:0.98413
# [750]	validation_0-rmse:0.98412
# [751]	validation_0-rmse:0.98411
# [752]	validation_0-rmse:0.98412
# [753]	validation_0-rmse:0.98411
# [754]	validation_0-rmse:0.98408
# [755]	validation_0-rmse:0.98405
# [756]	validation_0-rmse:0.98406
# [757]	validation_0-rmse:0.98406
# [758]	validation_0-rmse:0.98404
# [759]	validation_0-rmse:0.98404
# [760]	validation_0-rmse:0.98406
# [761]	validation_0-rmse:0.98406
# [762]	validation_0-rmse:0.98407
# [763]	validation_0-rmse:0.98406
# [764]	validation_0-rmse:0.98401
# [765]	validation_0-rmse:0.98399
# [766]	validation_0-rmse:0.98397
# [767]	validation_0-rmse:0.98397
# [768]	validation_0-rmse:0.98395
# [769]	validation_0-rmse:0.98395
# [770]	validation_0-rmse:0.98393
# [771]	validation_0-rmse:0.98390
# [772]	validation_0-rmse:0.98389
# [773]	validation_0-rmse:0.98390
# [774]	validation_0-rmse:0.98389
# [775]	validation_0-rmse:0.98390
# [776]	validation_0-rmse:0.98389
# [777]	validation_0-rmse:0.98388
# [778]	validation_0-rmse:0.98386
# [779]	validation_0-rmse:0.98387
# [780]	validation_0-rmse:0.98386
# [781]	validation_0-rmse:0.98383
# [782]	validation_0-rmse:0.98384
# [783]	validation_0-rmse:0.98383
# [784]	validation_0-rmse:0.98383
# [785]	validation_0-rmse:0.98381
# [786]	validation_0-rmse:0.98380
# [787]	validation_0-rmse:0.98381
# [788]	validation_0-rmse:0.98380
# [789]	validation_0-rmse:0.98380
# [790]	validation_0-rmse:0.98380
# [791]	validation_0-rmse:0.98379
# [792]	validation_0-rmse:0.98379
# [793]	validation_0-rmse:0.98379
# [794]	validation_0-rmse:0.98379
# [795]	validation_0-rmse:0.98377
# [796]	validation_0-rmse:0.98378
# [797]	validation_0-rmse:0.98373
# [798]	validation_0-rmse:0.98372
# [799]	validation_0-rmse:0.98372
# [800]	validation_0-rmse:0.98373
# [801]	validation_0-rmse:0.98371
# [802]	validation_0-rmse:0.98369
# [803]	validation_0-rmse:0.98366
# [804]	validation_0-rmse:0.98365
# [805]	validation_0-rmse:0.98365
# [806]	validation_0-rmse:0.98367
# [807]	validation_0-rmse:0.98363
# [808]	validation_0-rmse:0.98362
# [809]	validation_0-rmse:0.98360
# [810]	validation_0-rmse:0.98362
# [811]	validation_0-rmse:0.98361
# [812]	validation_0-rmse:0.98359
# [813]	validation_0-rmse:0.98358
# [814]	validation_0-rmse:0.98358
# [815]	validation_0-rmse:0.98360
# [816]	validation_0-rmse:0.98361
# [817]	validation_0-rmse:0.98361
# [818]	validation_0-rmse:0.98361
# [819]	validation_0-rmse:0.98361
# [820]	validation_0-rmse:0.98360
# [821]	validation_0-rmse:0.98358
# [822]	validation_0-rmse:0.98356
# [823]	validation_0-rmse:0.98353
# [824]	validation_0-rmse:0.98353
# [825]	validation_0-rmse:0.98351
# [826]	validation_0-rmse:0.98350
# [827]	validation_0-rmse:0.98351
# [828]	validation_0-rmse:0.98351
# [829]	validation_0-rmse:0.98350
# [830]	validation_0-rmse:0.98348
# [831]	validation_0-rmse:0.98349
# [832]	validation_0-rmse:0.98347
# [833]	validation_0-rmse:0.98345
# [834]	validation_0-rmse:0.98344
# [835]	validation_0-rmse:0.98345
# [836]	validation_0-rmse:0.98347
# [837]	validation_0-rmse:0.98347
# [838]	validation_0-rmse:0.98345
# [839]	validation_0-rmse:0.98342
# [840]	validation_0-rmse:0.98341
# [841]	validation_0-rmse:0.98343
# [842]	validation_0-rmse:0.98341
# [843]	validation_0-rmse:0.98340
# [844]	validation_0-rmse:0.98337
# [845]	validation_0-rmse:0.98336
# [846]	validation_0-rmse:0.98336
# [847]	validation_0-rmse:0.98335
# [848]	validation_0-rmse:0.98336
# [849]	validation_0-rmse:0.98333
# [850]	validation_0-rmse:0.98335
# [851]	validation_0-rmse:0.98334
# [852]	validation_0-rmse:0.98334
# [853]	validation_0-rmse:0.98336
# [854]	validation_0-rmse:0.98333
# [855]	validation_0-rmse:0.98328
# [856]	validation_0-rmse:0.98328
# [857]	validation_0-rmse:0.98328
# [858]	validation_0-rmse:0.98329
# [859]	validation_0-rmse:0.98329
# [860]	validation_0-rmse:0.98325
# [861]	validation_0-rmse:0.98322
# [862]	validation_0-rmse:0.98321
# [863]	validation_0-rmse:0.98318
# [864]	validation_0-rmse:0.98315
# [865]	validation_0-rmse:0.98310
# [866]	validation_0-rmse:0.98309
# [867]	validation_0-rmse:0.98309
# [868]	validation_0-rmse:0.98312
# [869]	validation_0-rmse:0.98313
# [870]	validation_0-rmse:0.98312
# [871]	validation_0-rmse:0.98314
# [872]	validation_0-rmse:0.98313
# [873]	validation_0-rmse:0.98311
# [874]	validation_0-rmse:0.98313
# [875]	validation_0-rmse:0.98311
# [876]	validation_0-rmse:0.98312
# [877]	validation_0-rmse:0.98310
# [878]	validation_0-rmse:0.98310
# [879]	validation_0-rmse:0.98307
# [880]	validation_0-rmse:0.98305
# [881]	validation_0-rmse:0.98305
# [882]	validation_0-rmse:0.98304
# [883]	validation_0-rmse:0.98304
# [884]	validation_0-rmse:0.98303
# [885]	validation_0-rmse:0.98305
# [886]	validation_0-rmse:0.98303
# [887]	validation_0-rmse:0.98301
# [888]	validation_0-rmse:0.98300
# [889]	validation_0-rmse:0.98300
# [890]	validation_0-rmse:0.98297
# [891]	validation_0-rmse:0.98299
# [892]	validation_0-rmse:0.98296
# [893]	validation_0-rmse:0.98296
# [894]	validation_0-rmse:0.98295
# [895]	validation_0-rmse:0.98294
# [896]	validation_0-rmse:0.98295
# [897]	validation_0-rmse:0.98297
# [898]	validation_0-rmse:0.98297
# [899]	validation_0-rmse:0.98296
# [900]	validation_0-rmse:0.98297
# [901]	validation_0-rmse:0.98298
# [902]	validation_0-rmse:0.98296
# [903]	validation_0-rmse:0.98294
# [904]	validation_0-rmse:0.98294
# [905]	validation_0-rmse:0.98295
# [906]	validation_0-rmse:0.98294
# [907]	validation_0-rmse:0.98288
# [908]	validation_0-rmse:0.98286
# [909]	validation_0-rmse:0.98287
# [910]	validation_0-rmse:0.98286
# [911]	validation_0-rmse:0.98286
# [912]	validation_0-rmse:0.98285
# [913]	validation_0-rmse:0.98281
# [914]	validation_0-rmse:0.98283
# [915]	validation_0-rmse:0.98282
# [916]	validation_0-rmse:0.98282
# [917]	validation_0-rmse:0.98284
# [918]	validation_0-rmse:0.98282
# [919]	validation_0-rmse:0.98282
# [920]	validation_0-rmse:0.98283
# [921]	validation_0-rmse:0.98278
# [922]	validation_0-rmse:0.98278
# [923]	validation_0-rmse:0.98276
# [924]	validation_0-rmse:0.98274
# [925]	validation_0-rmse:0.98273
# [926]	validation_0-rmse:0.98271
# [927]	validation_0-rmse:0.98272
# [928]	validation_0-rmse:0.98271
# [929]	validation_0-rmse:0.98269
# [930]	validation_0-rmse:0.98272
# [931]	validation_0-rmse:0.98270
# [932]	validation_0-rmse:0.98267
# [933]	validation_0-rmse:0.98267
# [934]	validation_0-rmse:0.98268
# [935]	validation_0-rmse:0.98269
# [936]	validation_0-rmse:0.98267
# [937]	validation_0-rmse:0.98267
# [938]	validation_0-rmse:0.98266
# [939]	validation_0-rmse:0.98266
# [940]	validation_0-rmse:0.98262
# [941]	validation_0-rmse:0.98262
# [942]	validation_0-rmse:0.98260
# [943]	validation_0-rmse:0.98258
# [944]	validation_0-rmse:0.98258
# [945]	validation_0-rmse:0.98255
# [946]	validation_0-rmse:0.98257
# [947]	validation_0-rmse:0.98259
# [948]	validation_0-rmse:0.98257
# [949]	validation_0-rmse:0.98258
# [950]	validation_0-rmse:0.98258
# [951]	validation_0-rmse:0.98258
# [952]	validation_0-rmse:0.98259
# [953]	validation_0-rmse:0.98256
# [954]	validation_0-rmse:0.98254
# [955]	validation_0-rmse:0.98255
# [956]	validation_0-rmse:0.98260
# [957]	validation_0-rmse:0.98260
# [958]	validation_0-rmse:0.98260
# [959]	validation_0-rmse:0.98258
# [960]	validation_0-rmse:0.98260
# [961]	validation_0-rmse:0.98258
# [962]	validation_0-rmse:0.98258
# [963]	validation_0-rmse:0.98258
# [964]	validation_0-rmse:0.98254
# [965]	validation_0-rmse:0.98254
# [966]	validation_0-rmse:0.98254
# [967]	validation_0-rmse:0.98251
# [968]	validation_0-rmse:0.98246
# [969]	validation_0-rmse:0.98242
# [970]	validation_0-rmse:0.98243
# [971]	validation_0-rmse:0.98240
# [972]	validation_0-rmse:0.98240
# [973]	validation_0-rmse:0.98242
# [974]	validation_0-rmse:0.98243
# [975]	validation_0-rmse:0.98242
# [976]	validation_0-rmse:0.98244
# [977]	validation_0-rmse:0.98240
# [978]	validation_0-rmse:0.98240
# [979]	validation_0-rmse:0.98239
# [980]	validation_0-rmse:0.98236
# [981]	validation_0-rmse:0.98236
# [982]	validation_0-rmse:0.98236
# [983]	validation_0-rmse:0.98236
# [984]	validation_0-rmse:0.98234
# [985]	validation_0-rmse:0.98232
# [986]	validation_0-rmse:0.98233
# [987]	validation_0-rmse:0.98231
# [988]	validation_0-rmse:0.98232
# [989]	validation_0-rmse:0.98232
# [990]	validation_0-rmse:0.98233
# [991]	validation_0-rmse:0.98230
# [992]	validation_0-rmse:0.98227
# [993]	validation_0-rmse:0.98228
# [994]	validation_0-rmse:0.98227
# [995]	validation_0-rmse:0.98228
# [996]	validation_0-rmse:0.98226
# [997]	validation_0-rmse:0.98226
# [998]	validation_0-rmse:0.98223
# [999]	validation_0-rmse:0.98227
# XGBoost Validation Log MSE: 0.9649677251301894
# XGBoost Validation R²: 0.3650225715208254
# XGBoost Test Log MSE: 2.823053486113462
# XGBoost Test R²: -0.00962724833433981
#
# Sample Predictions (XGB):
# Actual: 114, Predicted: 364
# Actual: 68, Predicted: 127
# Actual: 122, Predicted: 45
# Actual: 100, Predicted: 66
# Actual: 94, Predicted: 23
# Actual: 70, Predicted: 28
# Actual: 144, Predicted: 20
# Actual: 113, Predicted: 64
# Actual: 86, Predicted: 69
# Actual: 59, Predicted: 34

# %%
import json
import re
import numpy as np
from datetime import datetime

# Path to your new file with 3000 lines
test_file_path = "test-regression-round3.jsonl"

# Output file path
output_file_path = "prediction-regression-round3.json"

# Dictionary to store predictions: { post_id: predicted_like_count }
predictions_dict = {}

# -------------------------------------------------------------------
# 1) Function: Extract features for a single post
#    Mimics your training pipeline (same columns, same order).
# -------------------------------------------------------------------
def extract_single_post_features(post_json):
    """
    Given a single post (dict) with keys like 'caption', 'comments_count', etc.,
    return a 1D numpy array of features in the same order as the training code.
    """
    caption = post_json.get("caption", "") or ""

    # Basic text features
    caption_length = len(caption)
    hashtag_count  = caption.count("#")
    mention_count  = caption.count("@")

    # Additional text features
    words = caption.strip().split()
    word_count = len(words)
    avg_word_len = 0.0
    if word_count > 0:
        avg_word_len = sum(len(w) for w in words) / word_count
    emoji_count       = len(re.findall(r'[^\w\s,.;?!@#]', caption))
    exclamation_count = caption.count('!')
    question_count    = caption.count('?')
    link_presence     = 1 if ('http' in caption or 'www' in caption) else 0

    comments_count = post_json.get("comments_count", 0) or 0
    media_type     = 1 if post_json.get("media_type") == "IMAGE" else 0

    # Time-based features
    timestamp = post_json.get("timestamp")
    hour    = 0
    weekday = 0
    weekend = 0
    if timestamp:
        dt = datetime.fromisoformat(timestamp)
        hour = dt.hour
        weekday = dt.weekday()
        weekend = 1 if dt.weekday() >= 5 else 0

    # Return in the same order you used in training
    feature_vector = np.array([
        caption_length,
        hashtag_count,
        mention_count,
        comments_count,
        media_type,
        hour,
        weekday,
        weekend,
        word_count,
        avg_word_len,
        emoji_count,
        exclamation_count,
        question_count,
        link_presence
    ], dtype=float)  # float to ensure consistent shape for scaling

    return feature_vector

# -------------------------------------------------------------------
# 2) Read the new test .jsonl file line by line, build feature matrix
#    Then scale and predict with xgb_model
# -------------------------------------------------------------------
all_ids       = []
all_features  = []

with open(test_file_path, "r", encoding="utf-8") as fh:
    for line in fh:
        line = line.strip()
        if not line:
            continue  # skip empty lines
        post_json = json.loads(line)

        post_id = post_json.get("id")
        if not post_id:
            # If there's no 'id', skip or handle differently
            continue

        # Extract feature vector for this post
        feat_vec = extract_single_post_features(post_json)

        # Keep track of post_id and features
        all_ids.append(post_id)
        all_features.append(feat_vec)

# Convert to numpy array for batch scaling/prediction
all_features = np.array(all_features)

# -------------------------------------------------------------------
# 3) Scale the hour & weekday columns (indices [5, 6]) using
#    the *same scaler* you trained previously.
#    NOTE: We assume 'scaler' is already in memory.
# -------------------------------------------------------------------
all_features[:, 5:7] = scaler.transform(all_features[:, 5:7])

# -------------------------------------------------------------------
# 4) Predict using your trained XGB model
#    (We assume 'xgb_model' is loaded & in memory)
# -------------------------------------------------------------------
pred_log = xgb_model.predict(all_features)  # log-space predictions
pred_likes = np.expm1(pred_log)            # revert from log space

# Round to int
pred_likes = np.round(pred_likes).astype(int)

# -------------------------------------------------------------------
# 5) Build predictions_dict and save to JSON
# -------------------------------------------------------------------
for pid, plike in zip(all_ids, pred_likes):
    predictions_dict[pid] = int(plike)  # ensure it's an int, not np.int

with open(output_file_path, "w", encoding="utf-8") as outf:
    json.dump(predictions_dict, outf, indent=4)

print(f"Saved predictions to {output_file_path}. Sample:")
# Print a small slice of the dictionary
sample_keys = list(predictions_dict.keys())[:5]
for k in sample_keys:
    print(f"{k}: {predictions_dict[k]}")
# Out:
# Saved predictions to prediction-regression-round3.json. Sample:
# 18299464882193238: 279
# 17870639199008459: 260
# 17976060503438195: 178
# 17980348256173250: 389
# 18030944311530609: 27
